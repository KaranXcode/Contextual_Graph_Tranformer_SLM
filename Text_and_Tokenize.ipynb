# %%
# !pip install docx2txt
# Out:
# Collecting docx2txt
#   Downloading docx2txt-0.9-py3-none-any.whl.metadata (529 bytes)
# Downloading docx2txt-0.9-py3-none-any.whl (4.0 kB)
# Installing collected packages: docx2txt
# Successfully installed docx2txt-0.9

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt

# Step 1: Define the root folder containing all product folders
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
output_folder = root_folder / "processed"
individual_docs_folder = output_folder / "individual_docs"
individual_docs_folder.mkdir(parents=True, exist_ok=True)

# Step 2: Collect all PDF and DOCX files recursively
pdf_files = list(root_folder.rglob("*.pdf"))
docx_files = list(root_folder.rglob("*.docx"))
all_files = pdf_files + docx_files

# Step 3: Define functions to extract text
def extract_text_from_pdf(file_path):
    try:
        doc = fitz.open(file_path)
        text = "\n".join([page.get_text() for page in doc])
        doc.close()
        return text
    except Exception as e:
        print(f"❌ Error reading PDF {file_path}: {e}")
        return ""

def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

# Step 4: Extract and save individual documents + build final corpus
merged_corpus = []
for i, file in enumerate(all_files):
    if file.suffix.lower() == ".pdf":
        text = extract_text_from_pdf(file)
    elif file.suffix.lower() == ".docx":
        text = extract_text_from_docx(file)
    else:
        continue

    if text.strip():
        # Save to individual .txt file
        clean_name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")
        individual_file_path = individual_docs_folder / f"{clean_name}.txt"
        with open(individual_file_path, "w", encoding="utf-8") as f:
            f.write(text.strip())

        # Append to merged corpus
        merged_corpus.append(text.strip())

# Step 5: Save merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

print(f"✅ Preprocessing complete.")
print(f"📄 {len(merged_corpus)} documents processed.")
print(f"📁 Individual files saved in: {individual_docs_folder}")
print(f"📘 Merged corpus saved at: {merged_path}")
# Out:
# ✅ Preprocessing complete.
# 📄 601 documents processed.
# 📁 Individual files saved in: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files\processed\individual_docs
# 📘 Merged corpus saved at: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files\processed\abb_corpus.txt

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re

# Set paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
output_folder = root_folder / "processed_removedunwanted"
individual_docs_folder = output_folder / "individual_docs"
individual_docs_folder.mkdir(parents=True, exist_ok=True)

# Step 1: Collect all PDF and DOCX files recursively
pdf_files = list(root_folder.rglob("*.pdf"))
docx_files = list(root_folder.rglob("*.docx"))
all_files = pdf_files + docx_files

# Step 2: Define regex patterns for cleaning
noise_patterns = [
    r"^Contents\b.*",  # Table of contents header
    r"^Page\s+\d+",
    r"^ABB\s*$",
    r"^Wireless Controller.*",
    r"^Product version.*",
    r"^Issued.*",
    r"^Revision.*",
    r"^Figure\s+\d+\..*",
    r"^GUID-[\w\-]+",
    r"^© Copyright.*",
    r"^All rights reserved.*",
    r"^Trademarks.*",
    r"^Disclaimer.*",
    r"^\s*-+\s*$",
    r"^\s*$"
]
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

# Step 3: Define text extractors
def extract_text_from_pdf(file_path):
    try:
        doc = fitz.open(file_path)
        text = "\n".join([page.get_text() for page in doc])
        doc.close()
        return text
    except Exception as e:
        print(f"❌ Error reading PDF {file_path}: {e}")
        return ""

def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

def clean_text(text):
    cleaned_lines = []
    for line in text.splitlines():
        if not noise_regex.match(line.strip()):
            cleaned_lines.append(line.strip())
    return "\n".join(cleaned_lines).strip()

# Step 4: Process files, save clean individual and merged corpus
merged_corpus = []

for i, file in enumerate(all_files):
    if file.suffix.lower() == ".pdf":
        raw_text = extract_text_from_pdf(file)
    elif file.suffix.lower() == ".docx":
        raw_text = extract_text_from_docx(file)
    else:
        continue

    cleaned = clean_text(raw_text)
    if cleaned:
        # Save individual cleaned file
        name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")
        file_path = individual_docs_folder / f"{name}.txt"
        with open(file_path, "w", encoding="utf-8") as f:
            f.write(cleaned)
        merged_corpus.append(cleaned)

# Step 5: Save final merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

print(f"✅ Preprocessing complete.")
print(f"📄 {len(merged_corpus)} cleaned documents saved to: {individual_docs_folder}")
print(f"📘 Merged corpus saved at: {merged_path}")
# Out:
# ✅ Preprocessing complete.
# 📄 601 cleaned documents saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files\processed_removedunwanted\individual_docs
# 📘 Merged corpus saved at: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files\processed_removedunwanted\abb_corpus.txt

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re

# Set paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
root2_folder=Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data")
output_folder = root2_folder / "processed_removedunwanted_images"
individual_docs_folder = output_folder / "individual_docs"
images_folder = output_folder / "extracted_images"
individual_docs_folder.mkdir(parents=True, exist_ok=True)
images_folder.mkdir(parents=True, exist_ok=True)

# Collect all PDF and DOCX files
pdf_files = list(root_folder.rglob("*.pdf"))
docx_files = list(root_folder.rglob("*.docx"))
all_files = pdf_files + docx_files

# Regex patterns for cleaning unwanted text
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

# Text extraction and cleaning
def extract_text_from_pdf(file_path):
    try:
        doc = fitz.open(file_path)
        text = "\n".join([page.get_text() for page in doc])
        doc.close()
        return text
    except Exception as e:
        print(f"❌ Error reading PDF {file_path}: {e}")
        return ""

def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

def clean_text(text):
    cleaned_lines = [line.strip() for line in text.splitlines() if not noise_regex.match(line.strip())]
    return "\n".join(cleaned_lines).strip()

# Image extractor from PDFs
def extract_images_from_pdf(pdf_path, base_name):
    try:
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            for img_index, img in enumerate(doc.get_page_images(page_num)):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_path = images_folder / f"{base_name}_p{page_num+1}_img{img_index+1}.{image_ext}"
                with open(image_path, "wb") as f:
                    f.write(image_bytes)
        doc.close()
    except Exception as e:
        print(f"⚠️ Error extracting image from {pdf_path}: {e}")

# Process all documents
merged_corpus = []

for i, file in enumerate(all_files):
    name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")

    if file.suffix.lower() == ".pdf":
        raw_text = extract_text_from_pdf(file)
        extract_images_from_pdf(file, name)
    elif file.suffix.lower() == ".docx":
        raw_text = extract_text_from_docx(file)
    else:
        continue

    cleaned = clean_text(raw_text)
    if cleaned:
        txt_path = individual_docs_folder / f"{name}.txt"
        with open(txt_path, "w", encoding="utf-8") as f:
            f.write(cleaned)
        merged_corpus.append(cleaned)

# Save merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

# Summary
print(f"✅ Preprocessing complete.")
print(f"📄 {len(merged_corpus)} cleaned documents saved to: {individual_docs_folder}")
print(f"🖼️ Extracted images saved to: {images_folder}")
print(f"📘 Merged corpus saved at: {merged_path}")
# Out:
# ✅ Preprocessing complete.
# 📄 601 cleaned documents saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removedunwanted_images\individual_docs
# 🖼️ Extracted images saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removedunwanted_images\extracted_images
# 📘 Merged corpus saved at: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removedunwanted_images\abb_corpus.txt

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re

# Set paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
root2_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data")
output_folder = root2_folder / "processed_filtered"
individual_docs_folder = output_folder / "individual_docs"
images_folder = output_folder / "extracted_images"
individual_docs_folder.mkdir(parents=True, exist_ok=True)
images_folder.mkdir(parents=True, exist_ok=True)

# Noise patterns
noise_patterns = [
    r"^Contents\b.*", r"^Page\s+\d+", r"^ABB\s*$",
    r"^Product version.*", r"^Issued.*", r"^Revision.*",
    r"^Figure\s+\d+\..*", r"^GUID-[\w\-]+",
    r"^© Copyright.*", r"^All rights reserved.*",
    r"^Trademarks.*", r"^Disclaimer.*",
    r"^\s*-+\s*$", r"^\s*$"
]
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

def is_near_image(block_rect, image_rects, margin=30):
    """Check if block overlaps or is very close to any image"""
    for img in image_rects:
        if (block_rect.intersects(img) or
            abs(block_rect.y0 - img.y1) < margin or
            abs(block_rect.y1 - img.y0) < margin):
            return True
    return False

def extract_clean_text_from_pdf(file_path):
    """Extract text from PDF excluding regions near images"""
    text_blocks = []
    try:
        doc = fitz.open(file_path)
        for page in doc:
            image_rects = [fitz.Rect(img[1:5]) for img in page.get_images(full=True)]
            for block in page.get_text("blocks"):
                rect = fitz.Rect(block[:4])
                text = block[4].strip()
                if not is_near_image(rect, image_rects) and text and not noise_regex.match(text):
                    text_blocks.append(text)
        doc.close()
        return "\n".join(text_blocks)
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return ""

def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

def extract_images_from_pdf(pdf_path, base_name):
    try:
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            for img_index, img in enumerate(doc.get_page_images(page_num)):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_path = images_folder / f"{base_name}_p{page_num+1}_img{img_index+1}.{image_ext}"
                with open(image_path, "wb") as f:
                    f.write(image_bytes)
        doc.close()
    except Exception as e:
        print(f"⚠️ Error extracting image from {pdf_path}: {e}")

# Process files
pdf_files = list(root_folder.rglob("*.pdf"))
docx_files = list(root_folder.rglob("*.docx"))
all_files = pdf_files + docx_files
merged_corpus = []

for i, file in enumerate(all_files):
    name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")

    if file.suffix.lower() == ".pdf":
        raw_text = extract_clean_text_from_pdf(file)
        extract_images_from_pdf(file, name)
    elif file.suffix.lower() == ".docx":
        raw_text = extract_text_from_docx(file)
    else:
        continue

    if raw_text.strip():
        txt_path = individual_docs_folder / f"{name}.txt"
        with open(txt_path, "w", encoding="utf-8") as f:
            f.write(raw_text.strip())
        merged_corpus.append(raw_text.strip())

# Save final merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

print(f"✅ Done. Cleaned text saved to {individual_docs_folder}")
print(f"🖼️ Images saved to {images_folder}")
print(f"📘 Merged corpus: {merged_path}")
# Out:
# ✅ Done. Cleaned text saved to C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_filtered\individual_docs
# 🖼️ Images saved to C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_filtered\extracted_images
# 📘 Merged corpus: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_filtered\abb_corpus.txt

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re

# Set paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
root2_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data")
output_folder = root2_folder / "processed_removed2words_new"
individual_docs_folder = output_folder / "individual_docs"
images_folder = output_folder / "extracted_images"
individual_docs_folder.mkdir(parents=True, exist_ok=True)
images_folder.mkdir(parents=True, exist_ok=True)

# Noise patterns
noise_patterns = [
    r"^Contents\\b.*", r"^Page\\s+\\d+", r"^ABB\\s*$",
    r"^Product version.*", r"^Issued.*", r"^Revision.*",
    r"^Figure\\s+\\d+\\..*", r"^GUID-[\\w\\-]+",
    r"^\\u00a9 Copyright.*", r"^All rights reserved.*",
    r"^Trademarks.*", r"^Disclaimer.*",
    r"^\s*-+\s*$", r"^\s*$"
]
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

def is_near_image(block_rect, image_rects, margin=30):
    for img in image_rects:
        if (block_rect.intersects(img) or
            abs(block_rect.y0 - img.y1) < margin or
            abs(block_rect.y1 - img.y0) < margin):
            return True
    return False

def is_meaningful(text, min_word_count=3):
    return len([w for w in text.split() if w.isalpha()]) >= min_word_count

def extract_clean_text_from_pdf(file_path):
    """Extract text from PDF excluding regions near images and low-quality lines."""
    text_blocks = []
    try:
        doc = fitz.open(file_path)
        for page in doc:
            image_rects = [fitz.Rect(img[1:5]) for img in page.get_images(full=True)]
            for block in page.get_text("blocks"):
                rect = fitz.Rect(block[:4])
                text = block[4].strip()
                
                # Skip image-area or empty block
                if is_near_image(rect, image_rects) or not text:
                    continue
                
                # Apply strict quality filters to each line in the block
                for line in text.splitlines():
                    line = line.strip()
                    if len(line) < 5:
                        continue  # Skip very short lines
                    words = line.split()
                    word_count = len(words)
                    if word_count < 4:
                        continue  # Skip short lines (likely table or figure fragments)
                    alpha_chars = sum(c.isalpha() for c in line)
                    total_chars = len(line)
                    if total_chars == 0 or (alpha_chars / total_chars) < 0.5:
                        continue  # Skip lines with mostly symbols/numbers
                    if not noise_regex.match(line):  # Skip known boilerplate patterns
                        text_blocks.append(line)
        doc.close()
        return "\n".join(text_blocks)
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return ""


def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

def extract_images_from_pdf(pdf_path, base_name):
    try:
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            for img_index, img in enumerate(doc.get_page_images(page_num)):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_path = images_folder / f"{base_name}_p{page_num+1}_img{img_index+1}.{image_ext}"
                with open(image_path, "wb") as f:
                    f.write(image_bytes)
        doc.close()
    except Exception as e:
        print(f"⚠️ Error extracting image from {pdf_path}: {e}")

# Process files
pdf_files = list(root_folder.rglob("*.pdf"))
docx_files = list(root_folder.rglob("*.docx"))
all_files = pdf_files + docx_files
merged_corpus = []

for i, file in enumerate(all_files):
    name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")

    if file.suffix.lower() == ".pdf":
        raw_text = extract_clean_text_from_pdf(file)
        extract_images_from_pdf(file, name)
    elif file.suffix.lower() == ".docx":
        raw_text = extract_text_from_docx(file)
    else:
        continue

    if raw_text.strip():
        txt_path = individual_docs_folder / f"{name}.txt"
        with open(txt_path, "w", encoding="utf-8") as f:
            f.write(raw_text.strip())
        merged_corpus.append(raw_text.strip())

# Save final merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

print(f"✅ Done. Cleaned text saved to {individual_docs_folder}")
print(f"🖼️ Images saved to {images_folder}")
print(f"📘 Merged corpus: {merged_path}")
# Out:
# ✅ Done. Cleaned text saved to C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removed2words_new\individual_docs
# 🖼️ Images saved to C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removed2words_new\extracted_images
# 📘 Merged corpus: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_removed2words_new\abb_corpus.txt

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re

# Paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
root2_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data")
output_folder = root2_folder / "processed_final"
individual_docs_folder = output_folder / "individual_docs"
images_folder = output_folder / "extracted_images"
individual_docs_folder.mkdir(parents=True, exist_ok=True)
images_folder.mkdir(parents=True, exist_ok=True)

# Noise patterns
noise_patterns = [
    r"^Contents\b.*", r"^Page\s+\d+", r"^ABB\s*$",
    r"^Product version.*", r"^Issued.*", r"^Revision.*",
    r"^Figure\s+\d+\..*", r"^GUID-[\w\-]+", r"^© Copyright.*",
    r"^All rights reserved.*", r"^Trademarks.*", r"^Disclaimer.*",
    r"^http[s]?://.*", r"^\s*-+\s*$", r"^\s*$"
]
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

# Utility functions
def is_near_image(block_rect, image_rects, margin=30):
    for img in image_rects:
        if (block_rect.intersects(img) or
            abs(block_rect.y0 - img.y1) < margin or
            abs(block_rect.y1 - img.y0) < margin):
            return True
    return False

def is_meaningful(line):
    words = line.split()
    if len(words) < 4:
        return False
    alpha_ratio = sum(c.isalpha() for c in line) / len(line)
    return alpha_ratio > 0.5

# Main PDF text extractor
def extract_clean_text_from_pdf(file_path):
    text_blocks = []
    try:
        doc = fitz.open(file_path)
        first_heading = None
        for page_num, page in enumerate(doc):
            if page_num == 0:
                # Capture the title on the first page
                blocks = page.get_text("dict")["blocks"]
                titles = [
                    block["lines"][0]["spans"][0]["text"].strip()
                    for block in blocks
                    if block.get("lines") and block["lines"][0]["spans"][0]["size"] > 15  # Likely headings
                ]
                if titles:
                    first_heading = " ".join(titles).strip()
            
            image_rects = [fitz.Rect(img[1:5]) for img in page.get_images(full=True)]
            for block in page.get_text("blocks"):
                rect = fitz.Rect(block[:4])
                text = block[4].strip()
                if is_near_image(rect, image_rects) or not text:
                    continue
                for line in text.splitlines():
                    line = line.strip()
                    if noise_regex.match(line):
                        continue
                    if is_meaningful(line):
                        text_blocks.append(line)
        doc.close()
        if first_heading:
            return f"{first_heading}\n\n" + "\n".join(text_blocks)
        return "\n".join(text_blocks)
    except Exception as e:
        print(f"❌ Error processing {file_path}: {e}")
        return ""

# DOCX extractor
def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        print(f"❌ Error reading DOCX {file_path}: {e}")
        return ""

# Image extractor
def extract_images_from_pdf(pdf_path, base_name):
    try:
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            for img_index, img in enumerate(doc.get_page_images(page_num)):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_path = images_folder / f"{base_name}_p{page_num+1}_img{img_index+1}.{image_ext}"
                with open(image_path, "wb") as f:
                    f.write(image_bytes)
        doc.close()
    except Exception as e:
        print(f"⚠️ Error extracting image from {pdf_path}: {e}")

# Process all files
all_files = list(root_folder.rglob("*.pdf")) + list(root_folder.rglob("*.docx"))
merged_corpus = []

for i, file in enumerate(all_files):
    name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")
    
    if file.suffix.lower() == ".pdf":
        raw_text = extract_clean_text_from_pdf(file)
        extract_images_from_pdf(file, name)
    elif file.suffix.lower() == ".docx":
        raw_text = extract_text_from_docx(file)
    else:
        continue

    if raw_text.strip():
        txt_path = individual_docs_folder / f"{name}.txt"
        with open(txt_path, "w", encoding="utf-8") as f:
            f.write(raw_text.strip())
        merged_corpus.append(raw_text.strip())

# Save final merged corpus
merged_path = output_folder / "abb_corpus.txt"
with open(merged_path, "w", encoding="utf-8") as f:
    for doc in merged_corpus:
        f.write(doc + "\n\n")

print(f"✅ Final preprocessing complete.")
print(f"📄 Individual text files saved to: {individual_docs_folder}")
print(f"🖼️ Images extracted to: {images_folder}")
print(f"📘 Merged corpus written to: {merged_path}")
# Out:
# ✅ Final preprocessing complete.
# 📄 Individual text files saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final\individual_docs
# 🖼️ Images extracted to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final\extracted_images
# 📘 Merged corpus written to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final\abb_corpus.txt
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.6-py3-none-any.whl.metadata (42 kB)
# Collecting pdfminer.six==20250327 (from pdfplumber)
#   Downloading pdfminer_six-20250327-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: Pillow>=9.1 in c:\users\inkared5\appdata\local\anaconda3\lib\site-packages (from pdfplumber) (10.4.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-4.30.1-py3-none-win_amd64.whl.metadata (48 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\inkared5\appdata\local\anaconda3\lib\site-packages (from pdfminer.six==20250327->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\inkared5\appdata\local\anaconda3\lib\site-packages (from pdfminer.six==20250327->pdfplumber) (43.0.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\inkared5\appdata\local\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\inkared5\appdata\local\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20250327->pdfplumber) (2.21)
# Downloading pdfplumber-0.11.6-py3-none-any.whl (60 kB)
# Downloading pdfminer_six-20250327-py3-none-any.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.6 MB 2.4 MB/s eta 0:00:03
#    ------------- -------------------------- 1.8/5.6 MB 4.8 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.6 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 5.2/5.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 6.5 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.0 MB ? eta -:--:--
#    -------------- ------------------------- 1.0/3.0 MB 249.2 kB/s eta 0:00:08
#    -------------- ------------------------- 1.0/3.0 MB 249.2 kB/s eta 0:00:08
#    ----------------- ---------------------- 1.3/3.0 MB 298.2 kB/s eta 0:00:06
#    ------------------------ --------------- 1.8/3.0 MB 416.0 kB/s eta 0:00:03
#    ------------------------ --------------- 1.8/3.0 MB 416.0 kB/s eta 0:00:03
#    ------------------------ --------------- 1.8/3.0 MB 416.0 kB/s eta 0:00:03
#    ------------------------ --------------- 1.8/3.0 MB 416.0 kB/s eta 0:00:03
#    ------------------------ --------------- 1.8/3.0 MB 416.0 kB/s eta 0:00:03
#    ---------------------------- ----------- 2.1/3.0 MB 375.2 kB/s eta 0:00:03
#    ---------------------------- ----------- 2.1/3.0 MB 375.2 kB/s eta 0:00:03
#    ------------------------------- -------- 2.4/3.0 MB 393.6 kB/s eta 0:00:02
#    ----------------------------------- ---- 2.6/3.0 MB 430.2 kB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 477.0 kB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20250327 pdfplumber-0.11.6 pypdfium2-4.30.1

# %%
import os
from pathlib import Path
import fitz  # PyMuPDF
import docx2txt
import re
import csv
from io import StringIO
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

# Check PyMuPDF version
if not hasattr(fitz.Page, "find_tables"):
    logger.error("PyMuPDF version does not support table extraction. Please upgrade to version 1.23.0 or higher.")
    raise ImportError("PyMuPDF version too old. Run 'pip install --upgrade pymupdf'.")

# Paths
root_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\abb_products_pdf_files")
root2_folder = Path(r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data")
output_folder = root2_folder / "processed_final_grok"
individual_docs_folder = output_folder / "individual_docs"
images_folder = output_folder / "extracted_images"
individual_docs_folder.mkdir(parents=True, exist_ok=True)
images_folder.mkdir(parents=True, exist_ok=True)

# Noise patterns
noise_patterns = [
    r"^Contents\b.*", r"^Page\s+\d+", r"^ABB\s*$",
    r"^Product version.*", r"^Issued.*", r"^Revision.*",
    r"^Figure\s+\d+\..*", r"^GUID-[\w\-]+", r"^© Copyright.*",
    r"^All rights reserved.*", r"^Trademarks.*", r"^Disclaimer.*",
    r"^http[s]?://.*", r"^\s*-+\s*$", r"^\s*$"
]
noise_regex = re.compile("|".join(noise_patterns), re.IGNORECASE)

# Utility functions
def is_near_image(block_rect, image_rects, margin=30):
    for img in image_rects:
        if (block_rect.intersects(img) or
            abs(block_rect.y0 - img.y1) < margin or
            abs(block_rect.y1 - img.y0) < margin):
            return True
    return False

def is_meaningful(line):
    words = line.split()
    if len(words) < 4:
        return False
    alpha_ratio = sum(c.isalpha() for c in line) / len(line)
    return alpha_ratio > 0.5

def extract_text_from_table_region(page, table_bbox):
    """Extract text from table region using text blocks method as fallback."""
    try:
        # Get text blocks within the table bounding box
        table_rect = fitz.Rect(table_bbox)
        blocks = page.get_text("dict", clip=table_rect)
        
        # Extract text from blocks and organize by position
        text_items = []
        for block in blocks.get("blocks", []):
            if "lines" in block:
                for line in block["lines"]:
                    for span in line["spans"]:
                        text = span["text"].strip()
                        if text:
                            bbox = span["bbox"]
                            text_items.append({
                                "text": text,
                                "x0": bbox[0],
                                "y0": bbox[1],
                                "x1": bbox[2],
                                "y1": bbox[3]
                            })
        
        # Sort by vertical position first, then horizontal
        text_items.sort(key=lambda x: (x["y0"], x["x0"]))
        
        # Group items into rows based on vertical position
        rows = []
        current_row = []
        current_y = None
        tolerance = 5  # pixels tolerance for same row
        
        for item in text_items:
            if current_y is None or abs(item["y0"] - current_y) <= tolerance:
                current_row.append(item)
                current_y = item["y0"] if current_y is None else current_y
            else:
                if current_row:
                    # Sort current row by horizontal position
                    current_row.sort(key=lambda x: x["x0"])
                    rows.append([item["text"] for item in current_row])
                current_row = [item]
                current_y = item["y0"]
        
        # Add the last row
        if current_row:
            current_row.sort(key=lambda x: x["x0"])
            rows.append([item["text"] for item in current_row])
        
        return rows
    except Exception as e:
        logger.warning(f"Error extracting text from table region: {e}")
        return []

def format_table_to_text(page, table):
    """Convert a table to a CSV-like text format with proper text extraction."""
    try:
        if not table:
            logger.warning("Empty table encountered.")
            return ""
        
        output = StringIO()
        writer = csv.writer(output, lineterminator='\n')
        
        # First, try to extract using PyMuPDF's table extraction
        try:
            table_data = table.extract()
            if table_data and len(table_data) > 0:
                # Check if we got actual text content
                sample_cell = str(table_data[0][0]) if table_data[0] else ""
                if not (sample_cell.startswith("(") and "," in sample_cell and sample_cell.endswith(")")):
                    # We got actual text, not coordinates
                    for row in table_data:
                        cleaned_row = []
                        for cell in row:
                            cell_text = str(cell).strip() if cell is not None else ""
                            cleaned_row.append(cell_text)
                        if any(cleaned_row):  # Only add non-empty rows
                            writer.writerow(cleaned_row)
                    
                    table_text = output.getvalue()
                    output.close()
                    return table_text if table_text.strip() else ""
        except Exception as e:
            logger.warning(f"PyMuPDF table extraction failed: {e}")
        
        # Fallback: Extract text from table region using coordinate-based method
        logger.info("Using fallback text extraction for table")
        table_bbox = table.bbox
        rows = extract_text_from_table_region(page, table_bbox)
        
        if rows:
            for row in rows:
                if any(cell.strip() for cell in row):  # Only add rows with content
                    writer.writerow(row)
            
            table_text = output.getvalue()
            output.close()
            return table_text if table_text.strip() else ""
        
        output.close()
        return ""
        
    except Exception as e:
        logger.error(f"Error formatting table: {e}")
        return ""

def extract_tables_with_textboxes(page):
    """Alternative table extraction using text positioning analysis."""
    try:
        # Get all text with detailed positioning
        text_dict = page.get_text("dict")
        
        # Collect all text elements with their positions
        text_elements = []
        for block in text_dict.get("blocks", []):
            if "lines" in block:
                for line in block["lines"]:
                    for span in line["spans"]:
                        text = span["text"].strip()
                        if text and len(text) > 1:  # Filter out single characters
                            bbox = span["bbox"]
                            text_elements.append({
                                "text": text,
                                "x0": bbox[0],
                                "y0": bbox[1],
                                "x1": bbox[2],
                                "y1": bbox[3],
                                "size": span["size"]
                            })
        
        # Group elements that might form tables (similar y-coordinates, aligned x-coordinates)
        potential_tables = []
        processed_elements = set()
        
        for i, elem in enumerate(text_elements):
            if i in processed_elements:
                continue
                
            # Look for elements at similar y-level (potential row)
            row_elements = [elem]
            processed_elements.add(i)
            
            for j, other_elem in enumerate(text_elements[i+1:], i+1):
                if j in processed_elements:
                    continue
                    
                # Check if elements are on the same row (similar y-coordinates)
                if abs(elem["y0"] - other_elem["y0"]) <= 3:
                    row_elements.append(other_elem)
                    processed_elements.add(j)
            
            # If we found multiple elements in a row, it might be a table row
            if len(row_elements) >= 2:
                row_elements.sort(key=lambda x: x["x0"])  # Sort by x-coordinate
                potential_tables.append([elem["text"] for elem in row_elements])
        
        return potential_tables
        
    except Exception as e:
        logger.warning(f"Alternative table extraction failed: {e}")
        return []

# Main PDF text and table extractor
def extract_clean_text_from_pdf(file_path):
    text_blocks = []
    try:
        doc = fitz.open(file_path)
        first_heading = None
        
        for page_num, page in enumerate(doc):
            # Capture the title on the first page
            if page_num == 0:
                blocks = page.get_text("dict")["blocks"]
                titles = [
                    block["lines"][0]["spans"][0]["text"].strip()
                    for block in blocks
                    if block.get("lines") and block["lines"][0]["spans"] and block["lines"][0]["spans"][0]["size"] > 15
                ]
                if titles:
                    first_heading = " ".join(titles).strip()
            
            # Extract images to avoid text near them
            image_rects = [fitz.Rect(img[1:5]) for img in page.get_images(full=True)]
            
            # Extract tables using improved method
            tables_found = False
            try:
                tables = page.find_tables()
                for table in tables:
                    table_text = format_table_to_text(page, table)
                    if table_text.strip():
                        text_blocks.append("=== TABLE START ===")
                        text_blocks.append(table_text.strip())
                        text_blocks.append("=== TABLE END ===")
                        tables_found = True
                        logger.info(f"Successfully extracted table from page {page_num + 1}")
            except Exception as e:
                logger.warning(f"Primary table extraction failed for page {page_num + 1}: {e}")
            
            # If no tables found with primary method, try alternative approach
            if not tables_found:
                try:
                    alt_tables = extract_tables_with_textboxes(page)
                    if alt_tables and len(alt_tables) >= 2:  # At least 2 rows to consider it a table
                        text_blocks.append("=== TABLE START ===")
                        output = StringIO()
                        writer = csv.writer(output, lineterminator='\n')
                        for row in alt_tables:
                            writer.writerow(row)
                        table_text = output.getvalue()
                        output.close()
                        text_blocks.append(table_text.strip())
                        text_blocks.append("=== TABLE END ===")
                        logger.info(f"Alternative table extraction found {len(alt_tables)} rows on page {page_num + 1}")
                except Exception as e:
                    logger.warning(f"Alternative table extraction failed for page {page_num + 1}: {e}")
            
            # Extract non-tabular text
            for block in page.get_text("blocks"):
                rect = fitz.Rect(block[:4])
                text = block[4].strip()
                if is_near_image(rect, image_rects) or not text:
                    continue
                for line in text.splitlines():
                    line = line.strip()
                    if noise_regex.match(line):
                        continue
                    if is_meaningful(line):
                        text_blocks.append(line)
        
        doc.close()
        if first_heading:
            return f"{first_heading}\n\n" + "\n".join(text_blocks)
        return "\n".join(text_blocks)
    except Exception as e:
        logger.error(f"Error processing {file_path}: {e}")
        return ""

# DOCX extractor
def extract_text_from_docx(file_path):
    try:
        return docx2txt.process(file_path)
    except Exception as e:
        logger.error(f"Error reading DOCX {file_path}: {e}")
        return ""

# Image extractor
def extract_images_from_pdf(pdf_path, base_name):
    try:
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            for img_index, img in enumerate(doc.get_page_images(page_num)):
                xref = img[0]
                base_image = doc.extract_image(xref)
                image_bytes = base_image["image"]
                image_ext = base_image["ext"]
                image_path = images_folder / f"{base_name}_p{page_num+1}_img{img_index+1}.{image_ext}"
                with open(image_path, "wb") as f:
                    f.write(image_bytes)
        doc.close()
    except Exception as e:
        logger.error(f"Error extracting image from {pdf_path}: {e}")

# Process all files
all_files = list(root_folder.rglob("*.pdf")) + list(root_folder.rglob("*.docx"))
merged_corpus = []

logger.info(f"Found {len(all_files)} files to process")

for i, file in enumerate(all_files):
    name = f"{i:04d}__{file.stem}".replace(" ", "_").replace("/", "_")
    logger.info(f"Processing file {i+1}/{len(all_files)}: {file.name}")
    
    try:
        if file.suffix.lower() == ".pdf":
            raw_text = extract_clean_text_from_pdf(file)
            extract_images_from_pdf(file, name)
        elif file.suffix.lower() == ".docx":
            raw_text = extract_text_from_docx(file)
        else:
            logger.warning(f"Skipping unsupported file type: {file}")
            continue

        if raw_text.strip():
            txt_path = individual_docs_folder / f"{name}.txt"
            with open(txt_path, "w", encoding="utf-8") as f:
                f.write(raw_text.strip())
            merged_corpus.append(raw_text.strip())
            logger.info(f"✅ Successfully processed: {file.name}")
        else:
            logger.warning(f"No meaningful content extracted from {file}")
    except Exception as e:
        logger.error(f"Failed to process {file}: {e}")
        continue

# Save final merged corpus
merged_path = output_folder / "abb_corpus.txt"
try:
    with open(merged_path, "w", encoding="utf-8") as f:
        for doc in merged_corpus:
            f.write(doc + "\n\n" + "="*80 + "\n\n")
    logger.info(f"✅ Merged corpus written to: {merged_path}")
except Exception as e:
    logger.error(f"Error writing merged corpus to {merged_path}: {e}")

logger.info(f"✅ Final preprocessing complete!")
logger.info(f"📄 Individual text files saved to: {individual_docs_folder}")
logger.info(f"🖼️ Images extracted to: {images_folder}")
logger.info(f"📘 Merged corpus written to: {merged_path}")
logger.info(f"📊 Total files processed: {len(merged_corpus)}/{len(all_files)}")
# Out:
# 2025-06-10 12:33:54,587 - INFO - Found 608 files to process
# 2025-06-10 12:33:54,588 - INFO - Processing file 1/608: Wireless Controller ARC600, Product Guide.pdf
# 2025-06-10 12:33:54,849 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:33:55,082 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:33:55,656 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:33:55,785 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:33:56,500 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:33:56,612 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:33:56,686 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:33:56,688 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:33:56,971 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:33:56,977 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:33:57,098 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:33:57,281 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:33:57,296 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:33:57,381 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:33:57,403 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:33:57,614 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:33:57,839 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:33:57,844 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:33:57,861 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:33:58,286 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:33:58,291 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:33:58,294 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:33:58,299 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:33:58,307 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:33:58,571 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:33:58,585 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:33:58,596 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:33:58,859 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:33:58,873 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:33:58,883 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:33:58,918 - INFO - Successfully extracted table from page 19
# 2025-06-10 12:33:58,919 - INFO - Successfully extracted table from page 19
# 2025-06-10 12:33:59,304 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:33:59,309 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:33:59,319 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:33:59,363 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:33:59,584 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,585 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,586 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,588 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,589 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,591 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,592 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:33:59,647 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:33:59,652 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:01,194 - INFO - ✅ Successfully processed: Wireless Controller ARC600, Product Guide.pdf
# 2025-06-10 12:34:01,195 - INFO - Processing file 2/608: Wireless Gateway ARG600 ANSI, Product Guide.pdf
# 2025-06-10 12:34:01,321 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:01,631 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:01,751 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:02,512 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:02,622 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:02,709 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:02,719 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:02,812 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:02,917 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:03,113 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:03,115 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:03,122 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:03,127 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:03,237 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:03,251 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:03,442 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:03,448 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:03,450 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:03,453 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:03,838 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:03,849 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:03,856 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:03,901 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:03,945 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:03,949 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:04,794 - INFO - ✅ Successfully processed: Wireless Gateway ARG600 ANSI, Product Guide.pdf
# 2025-06-10 12:34:04,796 - INFO - Processing file 3/608: Wireless Gateway ARG600, Product Guide.pdf
# 2025-06-10 12:34:04,925 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:05,321 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:06,399 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:06,579 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:06,736 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:06,754 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:06,800 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:06,949 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:06,968 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:07,108 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:07,235 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:07,236 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:07,366 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:07,845 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:07,851 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:07,866 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:07,871 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:08,029 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:08,043 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:08,197 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:08,218 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:08,699 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:08,711 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:08,719 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:08,726 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:08,732 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:09,237 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:09,249 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:09,264 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:09,412 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:09,418 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:09,492 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:09,497 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:10,731 - INFO - ✅ Successfully processed: Wireless Gateway ARG600, Product Guide.pdf
# 2025-06-10 12:34:10,732 - INFO - Processing file 4/608: M2M Gateway ARM600, Product Guide.pdf
# 2025-06-10 12:34:10,853 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:10,954 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:11,468 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:11,541 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:11,631 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:11,701 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:11,938 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:11,941 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:11,950 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:12,067 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:12,074 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:12,133 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:12,138 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:12,697 - INFO - ✅ Successfully processed: M2M Gateway ARM600, Product Guide.pdf
# 2025-06-10 12:34:12,698 - INFO - Processing file 5/608: Wireless Protocol Gateway ARP600, Product Guide.pdf
# 2025-06-10 12:34:13,637 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:13,816 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:14,053 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:15,156 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:15,395 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:15,409 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:15,446 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:15,613 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:15,640 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:15,763 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:15,983 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:16,059 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:16,817 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:16,821 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:16,836 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:16,847 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:16,852 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:17,111 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:17,127 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:17,132 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:17,135 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:17,522 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:17,531 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:17,539 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:17,541 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:17,547 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:18,025 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:18,035 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:18,049 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:18,226 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:18,233 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:18,265 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:18,266 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:18,288 - INFO - Alternative table extraction found 3 rows on page 20
# 2025-06-10 12:34:19,635 - INFO - ✅ Successfully processed: Wireless Protocol Gateway ARP600, Product Guide.pdf
# 2025-06-10 12:34:19,636 - INFO - Processing file 6/608: 615 series, Cyber Security Deployment Guideline.pdf
# 2025-06-10 12:34:20,157 - INFO - Alternative table extraction found 7 rows on page 7
# 2025-06-10 12:34:20,242 - INFO - Alternative table extraction found 3 rows on page 9
# 2025-06-10 12:34:20,450 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:20,456 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:20,589 - INFO - Alternative table extraction found 9 rows on page 11
# 2025-06-10 12:34:20,743 - INFO - Alternative table extraction found 3 rows on page 13
# 2025-06-10 12:34:20,872 - INFO - Alternative table extraction found 2 rows on page 15
# 2025-06-10 12:34:20,978 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:21,185 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:21,341 - INFO - Alternative table extraction found 7 rows on page 18
# 2025-06-10 12:34:21,450 - INFO - Alternative table extraction found 6 rows on page 19
# 2025-06-10 12:34:21,519 - INFO - Alternative table extraction found 2 rows on page 20
# 2025-06-10 12:34:21,749 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:34:21,909 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:34:22,059 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:22,291 - INFO - Successfully extracted table from page 25
# 2025-06-10 12:34:22,630 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:22,648 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:22,778 - INFO - Successfully extracted table from page 27
# 2025-06-10 12:34:22,828 - INFO - Alternative table extraction found 13 rows on page 29
# 2025-06-10 12:34:22,878 - INFO - Alternative table extraction found 5 rows on page 30
# 2025-06-10 12:34:22,982 - INFO - Alternative table extraction found 10 rows on page 31
# 2025-06-10 12:34:23,153 - INFO - Alternative table extraction found 11 rows on page 32
# 2025-06-10 12:34:23,255 - INFO - Alternative table extraction found 13 rows on page 33
# 2025-06-10 12:34:23,335 - INFO - Alternative table extraction found 5 rows on page 34
# 2025-06-10 12:34:23,417 - INFO - Alternative table extraction found 26 rows on page 35
# 2025-06-10 12:34:23,485 - INFO - Alternative table extraction found 21 rows on page 36
# 2025-06-10 12:34:23,514 - INFO - Alternative table extraction found 3 rows on page 40
# 2025-06-10 12:34:24,985 - INFO - ✅ Successfully processed: 615 series, Cyber Security Deployment Guideline.pdf
# 2025-06-10 12:34:24,987 - INFO - Processing file 7/608: Firmware update release 5.1.22 for 615 series IEC product version 5.0 FP1 protection relays.pdf
# 2025-06-10 12:34:25,106 - INFO - Alternative table extraction found 11 rows on page 1
# 2025-06-10 12:34:25,246 - INFO - Alternative table extraction found 2 rows on page 3
# 2025-06-10 12:34:25,347 - INFO - Alternative table extraction found 6 rows on page 4
# 2025-06-10 12:34:25,751 - INFO - Alternative table extraction found 5 rows on page 10
# 2025-06-10 12:34:25,783 - INFO - ✅ Successfully processed: Firmware update release 5.1.22 for 615 series IEC product version 5.0 FP1 protection relays.pdf
# 2025-06-10 12:34:25,784 - INFO - Processing file 8/608: REACH SVHC declaration 240, Relion 611 series, 615 series, 620 series, 630 series, REX640, REX610, REF615R ANSI, RER615, REC615, RIO600, SMU615.pdf
# 2025-06-10 12:34:25,981 - INFO - Alternative table extraction found 16 rows on page 1
# 2025-06-10 12:34:26,141 - INFO - Alternative table extraction found 6 rows on page 2
# 2025-06-10 12:34:26,447 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:26,501 - INFO - Alternative table extraction found 6 rows on page 4
# 2025-06-10 12:34:26,533 - INFO - ✅ Successfully processed: REACH SVHC declaration 240, Relion 611 series, 615 series, 620 series, 630 series, REX640, REX610, REF615R ANSI, RER615, REC615, RIO600, SMU615.pdf
# 2025-06-10 12:34:26,535 - INFO - Processing file 9/608: REV615 5.0 FP1 IEC, Capacitor Bank Protection and Control, Product Guide.pdf
# 2025-06-10 12:34:26,843 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:27,054 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:27,420 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:27,433 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:27,442 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:28,150 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:28,161 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:28,180 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:28,194 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:34:30,404 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,409 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,451 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,464 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,475 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,484 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:30,504 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:34:31,526 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:31,534 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:31,557 - INFO - Successfully extracted table from page 7
# 2025-06-10 12:34:31,991 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:31,995 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:32,000 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:32,279 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:32,283 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:32,287 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:32,661 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:32,671 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:33,101 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:33,366 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:33,717 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:33,726 - INFO - Successfully extracted table from page 13
# 2025-06-10 12:34:33,902 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:34:34,332 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:34,372 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:34:35,012 - INFO - Successfully extracted table from page 16
# 2025-06-10 12:34:35,538 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:35,543 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:34:36,074 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:36,080 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:36,089 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:36,094 - INFO - Successfully extracted table from page 18
# 2025-06-10 12:34:36,290 - INFO - Successfully extracted table from page 19
# 2025-06-10 12:34:36,298 - INFO - Successfully extracted table from page 19
# 2025-06-10 12:34:36,830 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:34:36,843 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:34:36,860 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:34:36,872 - INFO - Successfully extracted table from page 20
# 2025-06-10 12:34:37,406 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:34:37,412 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:34:37,428 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:34:37,436 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:34:37,970 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:34:37,978 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:34:37,989 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:34:37,999 - INFO - Successfully extracted table from page 22
# 2025-06-10 12:34:38,571 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,577 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,579 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,588 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,592 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,598 - INFO - Successfully extracted table from page 23
# 2025-06-10 12:34:38,829 - INFO - Successfully extracted table from page 24
# 2025-06-10 12:34:38,842 - INFO - Successfully extracted table from page 24
# 2025-06-10 12:34:39,289 - INFO - Successfully extracted table from page 25
# 2025-06-10 12:34:39,296 - INFO - Successfully extracted table from page 25
# 2025-06-10 12:34:39,302 - INFO - Successfully extracted table from page 25
# 2025-06-10 12:34:39,308 - INFO - Successfully extracted table from page 25
# 2025-06-10 12:34:39,517 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:39,523 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:39,525 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:39,527 - INFO - Successfully extracted table from page 26
# 2025-06-10 12:34:39,801 - INFO - Successfully extracted table from page 27
# 2025-06-10 12:34:39,828 - INFO - Successfully extracted table from page 27
# 2025-06-10 12:34:39,844 - INFO - Successfully extracted table from page 27
# 2025-06-10 12:34:40,182 - INFO - Successfully extracted table from page 28
# 2025-06-10 12:34:40,198 - INFO - Successfully extracted table from page 28
# 2025-06-10 12:34:40,212 - INFO - Successfully extracted table from page 28
# 2025-06-10 12:34:40,422 - INFO - Successfully extracted table from page 29
# 2025-06-10 12:34:40,433 - INFO - Successfully extracted table from page 29
# 2025-06-10 12:34:40,735 - INFO - Successfully extracted table from page 30
# 2025-06-10 12:34:40,748 - INFO - Successfully extracted table from page 30
# 2025-06-10 12:34:40,756 - INFO - Successfully extracted table from page 30
# 2025-06-10 12:34:40,765 - INFO - Successfully extracted table from page 30
# 2025-06-10 12:34:41,331 - INFO - Successfully extracted table from page 31
# 2025-06-10 12:34:41,359 - INFO - Successfully extracted table from page 31
# 2025-06-10 12:34:41,369 - INFO - Successfully extracted table from page 31
# 2025-06-10 12:34:41,388 - INFO - Successfully extracted table from page 31
# 2025-06-10 12:34:41,873 - INFO - Successfully extracted table from page 32
# 2025-06-10 12:34:41,881 - INFO - Successfully extracted table from page 32
# 2025-06-10 12:34:41,909 - INFO - Successfully extracted table from page 32
# 2025-06-10 12:34:41,927 - INFO - Successfully extracted table from page 32
# 2025-06-10 12:34:42,683 - INFO - Successfully extracted table from page 33
# 2025-06-10 12:34:42,700 - INFO - Successfully extracted table from page 33
# 2025-06-10 12:34:42,717 - INFO - Successfully extracted table from page 33
# 2025-06-10 12:34:42,732 - INFO - Successfully extracted table from page 33
# 2025-06-10 12:34:43,290 - INFO - Successfully extracted table from page 34
# 2025-06-10 12:34:43,296 - INFO - Successfully extracted table from page 34
# 2025-06-10 12:34:43,312 - INFO - Successfully extracted table from page 34
# 2025-06-10 12:34:43,319 - INFO - Successfully extracted table from page 34
# 2025-06-10 12:34:43,326 - INFO - Successfully extracted table from page 34
# 2025-06-10 12:34:43,693 - INFO - Successfully extracted table from page 35
# 2025-06-10 12:34:43,705 - INFO - Successfully extracted table from page 35
# 2025-06-10 12:34:43,714 - INFO - Successfully extracted table from page 35
# 2025-06-10 12:34:43,732 - INFO - Successfully extracted table from page 35
# 2025-06-10 12:34:44,194 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:34:44,202 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:34:44,211 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:34:44,215 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:34:44,226 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:34:44,933 - INFO - Successfully extracted table from page 37
# 2025-06-10 12:34:44,962 - INFO - Successfully extracted table from page 37
# 2025-06-10 12:34:44,976 - INFO - Successfully extracted table from page 37
# 2025-06-10 12:34:44,992 - INFO - Successfully extracted table from page 37
# 2025-06-10 12:34:45,454 - INFO - Successfully extracted table from page 38
# 2025-06-10 12:34:45,467 - INFO - Successfully extracted table from page 38
# 2025-06-10 12:34:45,481 - INFO - Successfully extracted table from page 38
# 2025-06-10 12:34:45,498 - INFO - Successfully extracted table from page 38
# 2025-06-10 12:34:45,696 - INFO - Successfully extracted table from page 39
# 2025-06-10 12:34:45,710 - INFO - Successfully extracted table from page 39
# 2025-06-10 12:34:45,717 - INFO - Successfully extracted table from page 39
# 2025-06-10 12:34:45,844 - INFO - Successfully extracted table from page 40
# 2025-06-10 12:34:45,851 - INFO - Successfully extracted table from page 40
# 2025-06-10 12:34:45,965 - INFO - Successfully extracted table from page 41
# 2025-06-10 12:34:45,968 - INFO - Successfully extracted table from page 41
# 2025-06-10 12:34:45,973 - INFO - Successfully extracted table from page 41
# 2025-06-10 12:34:46,629 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:46,648 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:46,655 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:46,667 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:46,675 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:46,680 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:34:47,436 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:47,444 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:47,451 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:47,458 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:47,467 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:47,478 - INFO - Successfully extracted table from page 43
# 2025-06-10 12:34:48,135 - INFO - Successfully extracted table from page 44
# 2025-06-10 12:34:48,143 - INFO - Successfully extracted table from page 44
# 2025-06-10 12:34:48,152 - INFO - Successfully extracted table from page 44
# 2025-06-10 12:34:48,173 - INFO - Successfully extracted table from page 44
# 2025-06-10 12:34:48,176 - INFO - Successfully extracted table from page 44
# 2025-06-10 12:34:48,339 - INFO - Successfully extracted table from page 45
# 2025-06-10 12:34:48,342 - INFO - Successfully extracted table from page 45
# 2025-06-10 12:34:48,343 - INFO - Successfully extracted table from page 45
# 2025-06-10 12:34:48,346 - INFO - Successfully extracted table from page 45
# 2025-06-10 12:34:49,094 - INFO - Successfully extracted table from page 46
# 2025-06-10 12:34:49,099 - INFO - Successfully extracted table from page 46
# 2025-06-10 12:34:49,109 - INFO - Successfully extracted table from page 46
# 2025-06-10 12:34:49,959 - INFO - Successfully extracted table from page 47
# 2025-06-10 12:34:50,630 - INFO - Successfully extracted table from page 48
# 2025-06-10 12:34:50,648 - INFO - Successfully extracted table from page 48
# 2025-06-10 12:34:50,686 - INFO - Successfully extracted table from page 48
# 2025-06-10 12:34:50,971 - INFO - Successfully extracted table from page 49
# 2025-06-10 12:34:50,980 - INFO - Successfully extracted table from page 49
# 2025-06-10 12:34:51,279 - INFO - Successfully extracted table from page 50
# 2025-06-10 12:34:51,307 - INFO - Successfully extracted table from page 50
# 2025-06-10 12:34:51,685 - INFO - Successfully extracted table from page 51
# 2025-06-10 12:34:51,709 - INFO - Successfully extracted table from page 51
# 2025-06-10 12:34:51,994 - INFO - Successfully extracted table from page 52
# 2025-06-10 12:34:52,020 - INFO - Successfully extracted table from page 52
# 2025-06-10 12:34:52,144 - INFO - Successfully extracted table from page 53
# 2025-06-10 12:34:52,795 - INFO - Successfully extracted table from page 54
# 2025-06-10 12:34:52,798 - INFO - Successfully extracted table from page 54
# 2025-06-10 12:34:52,852 - INFO - Successfully extracted table from page 54
# 2025-06-10 12:34:53,722 - INFO - Successfully extracted table from page 55
# 2025-06-10 12:34:53,750 - INFO - Successfully extracted table from page 55
# 2025-06-10 12:34:53,758 - INFO - Successfully extracted table from page 55
# 2025-06-10 12:34:53,772 - INFO - Successfully extracted table from page 55
# 2025-06-10 12:34:54,924 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:34:54,929 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:34:54,947 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:34:54,968 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:34:54,981 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:34:55,275 - INFO - Successfully extracted table from page 57
# 2025-06-10 12:34:55,297 - INFO - Successfully extracted table from page 57
# 2025-06-10 12:34:55,308 - INFO - Successfully extracted table from page 57
# 2025-06-10 12:34:55,342 - INFO - Alternative table extraction found 3 rows on page 60
# 2025-06-10 12:34:57,092 - INFO - ✅ Successfully processed: REV615 5.0 FP1 IEC, Capacitor Bank Protection and Control, Product Guide.pdf
# 2025-06-10 12:34:57,094 - INFO - Processing file 10/608: SSL 3.0 Protocol Vulnerability and POODLE Attack in Relion 615 series v5.0.pdf
# 2025-06-10 12:34:57,443 - INFO - Successfully extracted table from page 1
# 2025-06-10 12:34:57,777 - INFO - Successfully extracted table from page 2
# 2025-06-10 12:34:58,041 - INFO - Successfully extracted table from page 3
# 2025-06-10 12:34:58,243 - INFO - Successfully extracted table from page 4
# 2025-06-10 12:34:58,267 - INFO - ✅ Successfully processed: SSL 3.0 Protocol Vulnerability and POODLE Attack in Relion 615 series v5.0.pdf
# 2025-06-10 12:34:58,270 - INFO - Processing file 11/608: CAP 501 ver. 2.4.0 Relay Setting Tools, Installation and Commissioning Manual.pdf
# 2025-06-10 12:34:58,536 - INFO - Alternative table extraction found 3 rows on page 3
# 2025-06-10 12:34:58,880 - INFO - Alternative table extraction found 6 rows on page 7
# 2025-06-10 12:34:59,305 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:59,311 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:59,317 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:34:59,482 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:34:59,577 - INFO - Successfully extracted table from page 10
# 2025-06-10 12:34:59,743 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:59,755 - INFO - Successfully extracted table from page 11
# 2025-06-10 12:34:59,802 - INFO - Successfully extracted table from page 12
# 2025-06-10 12:34:59,898 - INFO - Alternative table extraction found 11 rows on page 13
# 2025-06-10 12:35:00,076 - INFO - Alternative table extraction found 6 rows on page 14
# 2025-06-10 12:35:00,304 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:35:00,443 - INFO - Alternative table extraction found 2 rows on page 16
# 2025-06-10 12:35:00,528 - INFO - Alternative table extraction found 5 rows on page 17
# 2025-06-10 12:35:00,567 - INFO - Alternative table extraction found 2 rows on page 18
# 2025-06-10 12:35:00,638 - INFO - Alternative table extraction found 2 rows on page 20
# 2025-06-10 12:35:00,680 - INFO - Alternative table extraction found 2 rows on page 21
# 2025-06-10 12:35:00,725 - INFO - Alternative table extraction found 2 rows on page 22
# 2025-06-10 12:35:00,803 - INFO - Alternative table extraction found 2 rows on page 23
# 2025-06-10 12:35:00,879 - INFO - Alternative table extraction found 3 rows on page 24
# 2025-06-10 12:35:00,956 - INFO - Alternative table extraction found 2 rows on page 25
# 2025-06-10 12:35:01,108 - INFO - Alternative table extraction found 2 rows on page 26
# 2025-06-10 12:35:01,430 - INFO - Alternative table extraction found 3 rows on page 27
# 2025-06-10 12:35:01,598 - INFO - Alternative table extraction found 2 rows on page 28
# 2025-06-10 12:35:01,701 - INFO - Alternative table extraction found 2 rows on page 29
# 2025-06-10 12:35:01,783 - INFO - Alternative table extraction found 4 rows on page 30
# 2025-06-10 12:35:01,879 - INFO - Alternative table extraction found 5 rows on page 31
# 2025-06-10 12:35:01,938 - INFO - Alternative table extraction found 4 rows on page 32
# 2025-06-10 12:35:02,091 - INFO - Alternative table extraction found 4 rows on page 33
# 2025-06-10 12:35:02,259 - INFO - Alternative table extraction found 7 rows on page 35
# 2025-06-10 12:35:02,422 - INFO - Alternative table extraction found 4 rows on page 36
# 2025-06-10 12:35:02,493 - INFO - Alternative table extraction found 6 rows on page 37
# 2025-06-10 12:35:02,560 - INFO - Alternative table extraction found 2 rows on page 38
# 2025-06-10 12:35:02,622 - INFO - Alternative table extraction found 3 rows on page 39
# 2025-06-10 12:35:02,671 - INFO - Alternative table extraction found 2 rows on page 40
# 2025-06-10 12:35:02,759 - INFO - Alternative table extraction found 3 rows on page 41
# 2025-06-10 12:35:02,932 - INFO - Alternative table extraction found 6 rows on page 43
# 2025-06-10 12:35:03,074 - INFO - Alternative table extraction found 5 rows on page 44
# 2025-06-10 12:35:03,177 - INFO - Alternative table extraction found 5 rows on page 45
# 2025-06-10 12:35:03,262 - INFO - Alternative table extraction found 5 rows on page 46
# 2025-06-10 12:35:03,360 - INFO - Alternative table extraction found 5 rows on page 47
# 2025-06-10 12:35:03,401 - INFO - Alternative table extraction found 2 rows on page 48
# 2025-06-10 12:35:03,425 - INFO - Alternative table extraction found 2 rows on page 49
# 2025-06-10 12:35:03,473 - INFO - Alternative table extraction found 3 rows on page 50
# 2025-06-10 12:35:03,569 - INFO - Alternative table extraction found 2 rows on page 51
# 2025-06-10 12:35:04,132 - INFO - ✅ Successfully processed: CAP 501 ver. 2.4.0 Relay Setting Tools, Installation and Commissioning Manual.pdf
# 2025-06-10 12:35:04,134 - INFO - Processing file 12/608: CAP 501 ver. 2.4.0 Relay Setting Tools, Operator's manual.pdf
# 2025-06-10 12:35:04,330 - INFO - Alternative table extraction found 3 rows on page 3
# 2025-06-10 12:35:04,734 - INFO - Alternative table extraction found 6 rows on page 7
# 2025-06-10 12:35:04,995 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:35:05,001 - INFO - Successfully extracted table from page 8
# 2025-06-10 12:35:05,038 - INFO - Successfully extracted table from page 9
# 2025-06-10 12:35:05,110 - INFO - Alternative table extraction found 5 rows on page 11
# 2025-06-10 12:35:05,189 - INFO - Alternative table extraction found 7 rows on page 12
# 2025-06-10 12:35:05,322 - INFO - Alternative table extraction found 4 rows on page 13
# 2025-06-10 12:35:05,389 - INFO - Alternative table extraction found 7 rows on page 15
# 2025-06-10 12:35:05,462 - INFO - Alternative table extraction found 9 rows on page 16
# 2025-06-10 12:35:05,524 - INFO - Alternative table extraction found 3 rows on page 17
# 2025-06-10 12:35:05,593 - INFO - Alternative table extraction found 3 rows on page 18
# 2025-06-10 12:35:05,678 - INFO - Alternative table extraction found 2 rows on page 19
# 2025-06-10 12:35:05,728 - INFO - Alternative table extraction found 3 rows on page 20
# 2025-06-10 12:35:05,795 - INFO - Alternative table extraction found 2 rows on page 21
# 2025-06-10 12:35:05,909 - INFO - Alternative table extraction found 3 rows on page 23
# 2025-06-10 12:35:05,971 - INFO - Alternative table extraction found 7 rows on page 24
# 2025-06-10 12:35:06,095 - INFO - Alternative table extraction found 9 rows on page 25
# 2025-06-10 12:35:06,165 - INFO - Alternative table extraction found 2 rows on page 26
# 2025-06-10 12:35:06,322 - INFO - Alternative table extraction found 3 rows on page 28
# 2025-06-10 12:35:06,387 - INFO - Alternative table extraction found 2 rows on page 29
# 2025-06-10 12:35:06,584 - INFO - Successfully extracted table from page 30
# 2025-06-10 12:35:06,779 - INFO - Alternative table extraction found 2 rows on page 32
# 2025-06-10 12:35:06,879 - INFO - Alternative table extraction found 6 rows on page 33
# 2025-06-10 12:35:06,975 - INFO - Alternative table extraction found 10 rows on page 34
# 2025-06-10 12:35:07,049 - INFO - Alternative table extraction found 9 rows on page 35
# 2025-06-10 12:35:07,158 - INFO - Successfully extracted table from page 36
# 2025-06-10 12:35:07,267 - INFO - Alternative table extraction found 7 rows on page 37
# 2025-06-10 12:35:07,395 - INFO - Alternative table extraction found 6 rows on page 38
# 2025-06-10 12:35:07,545 - INFO - Alternative table extraction found 3 rows on page 39
# 2025-06-10 12:35:07,709 - INFO - Alternative table extraction found 5 rows on page 40
# 2025-06-10 12:35:07,835 - INFO - Alternative table extraction found 4 rows on page 41
# 2025-06-10 12:35:08,007 - INFO - Successfully extracted table from page 42
# 2025-06-10 12:35:08,126 - INFO - Alternative table extraction found 4 rows on page 43
# 2025-06-10 12:35:08,213 - INFO - Alternative table extraction found 4 rows on page 44
# 2025-06-10 12:35:08,333 - INFO - Alternative table extraction found 6 rows on page 45
# 2025-06-10 12:35:08,429 - INFO - Alternative table extraction found 7 rows on page 46
# 2025-06-10 12:35:08,471 - INFO - Alternative table extraction found 3 rows on page 47
# 2025-06-10 12:35:08,544 - INFO - Alternative table extraction found 7 rows on page 49
# 2025-06-10 12:35:08,758 - INFO - Successfully extracted table from page 50
# 2025-06-10 12:35:08,870 - INFO - Alternative table extraction found 8 rows on page 51
# 2025-06-10 12:35:09,086 - INFO - Alternative table extraction found 3 rows on page 52
# 2025-06-10 12:35:09,349 - INFO - Alternative table extraction found 4 rows on page 53
# 2025-06-10 12:35:09,573 - INFO - Alternative table extraction found 4 rows on page 54
# 2025-06-10 12:35:09,720 - INFO - Alternative table extraction found 4 rows on page 55
# 2025-06-10 12:35:09,866 - INFO - Alternative table extraction found 6 rows on page 56
# 2025-06-10 12:35:09,946 - INFO - Alternative table extraction found 4 rows on page 57
# 2025-06-10 12:35:10,068 - INFO - Alternative table extraction found 7 rows on page 59
# 2025-06-10 12:35:10,178 - INFO - Alternative table extraction found 4 rows on page 60
# 2025-06-10 12:35:10,302 - INFO - Alternative table extraction found 7 rows on page 61
# 2025-06-10 12:35:10,384 - INFO - Alternative table extraction found 3 rows on page 62
# 2025-06-10 12:35:10,472 - INFO - Alternative table extraction found 4 rows on page 63
# 2025-06-10 12:35:10,588 - INFO - Alternative table extraction found 7 rows on page 65
# 2025-06-10 12:35:10,804 - INFO - Alternative table extraction found 4 rows on page 67
# 2025-06-10 12:35:10,945 - INFO - Alternative table extraction found 4 rows on page 68
# 2025-06-10 12:35:11,092 - INFO - Alternative table extraction found 4 rows on page 69
# 2025-06-10 12:35:11,153 - INFO - Alternative table extraction found 3 rows on page 70
# 2025-06-10 12:35:11,212 - INFO - Alternative table extraction found 3 rows on page 71
# 2025-06-10 12:35:11,318 - INFO - Alternative table extraction found 8 rows on page 73
# 2025-06-10 12:35:11,410 - INFO - Alternative table extraction found 5 rows on page 74
# 2025-06-10 12:35:11,502 - INFO - Successfully extracted table from page 75
# 2025-06-10 12:35:11,626 - INFO - Successfully extracted table from page 76
# 2025-06-10 12:35:11,822 - INFO - Successfully extracted table from page 77
# 2025-06-10 12:35:11,902 - INFO - Successfully extracted table from page 78
# 2025-06-10 12:35:12,026 - INFO - Alternative table extraction found 2 rows on page 79
# 2025-06-10 12:35:12,115 - INFO - Successfully extracted table from page 80
# 2025-06-10 12:35:12,175 - INFO - Alternative table extraction found 3 rows on page 81
# 2025-06-10 12:35:12,283 - INFO - Alternative table extraction found 2 rows on page 82
# 2025-06-10 12:35:12,386 - INFO - Alternative table extraction found 6 rows on page 83
# 2025-06-10 12:35:12,509 - INFO - Alternative table extraction found 3 rows on page 84
# 2025-06-10 12:35:12,751 - INFO - Alternative table extraction found 2 rows on page 85
# 2025-06-10 12:35:14,298 - INFO - ✅ Successfully processed: CAP 501 ver. 2.4.0 Relay Setting Tools, Operator's manual.pdf
# 2025-06-10 12:35:14,300 - INFO - Processing file 13/608: CAP 501, Relay Setting Tools, Product Guide.pdf
# 2025-06-10 12:35:14,544 - INFO - Alternative table extraction found 22 rows on page 3
# 2025-06-10 12:35:14,874 - INFO - Alternative table extraction found 10 rows on page 4
# 2025-06-10 12:35:15,263 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:35:15,275 - INFO - Successfully extracted table from page 5
# 2025-06-10 12:35:15,495 - INFO - Successfully extracted table from page 6
# 2025-06-10 12:35:15,607 - INFO - ✅ Successfully processed: CAP 501, Relay Setting Tools, Product Guide.pdf
# 2025-06-10 12:35:15,608 - INFO - Processing file 14/608: CAP, LIB, SMS, Tools for Relays and Terminals, User's Guide.pdf
# 2025-06-10 12:35:16,024 - INFO - Alternative table extraction found 17 rows on page 3
# 2025-06-10 12:35:16,188 - INFO - Alternative table extraction found 22 rows on page 4
# 2025-06-10 12:35:16,341 - INFO - Alternative table extraction found 16 rows on page 5
# 2025-06-10 12:35:16,470 - INFO - Alternative table extraction found 9 rows on page 6
# 2025-06-10 12:35:16,590 - INFO - Alternative table extraction found 23 rows on page 7
# 2025-06-10 12:35:16,785 - INFO - Alternative table extraction found 21 rows on page 8
# 2025-06-10 12:35:16,905 - INFO - Alternative table extraction found 10 rows on page 9
# 2025-06-10 12:35:17,023 - INFO - Alternative table extraction found 12 rows on page 10
# 2025-06-10 12:35:17,153 - INFO - Alternative table extraction found 6 rows on page 13
# 2025-06-10 12:35:17,371 - INFO - Successfully extracted table from page 14
# 2025-06-10 12:35:17,505 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:35:17,512 - INFO - Successfully extracted table from page 15
# 2025-06-10 12:35:17,676 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:35:17,684 - INFO - Successfully extracted table from page 17
# 2025-06-10 12:35:17,759 - INFO - Alternative table extraction found 5 rows on page 18
# 2025-06-10 12:35:17,790 - INFO - Alternative table extraction found 2 rows on page 19
# 2025-06-10 12:35:17,878 - INFO - Alternative table extraction found 2 rows on page 20
# 2025-06-10 12:35:18,052 - INFO - Successfully extracted table from page 21
# 2025-06-10 12:35:18,203 - INFO - Alternative table extraction found 4 rows on page 23
# 2025-06-10 12:35:18,324 - INFO - Alternative table extraction found 7 rows on page 24
# 2025-06-10 12:35:18,377 - INFO - Alternative table extraction found 4 rows on page 25
# 2025-06-10 12:35:18,421 - INFO - Alternative table extraction found 2 rows on page 26
# 2025-06-10 12:35:18,576 - INFO - Alternative table extraction found 2 rows on page 29
# 2025-06-10 12:35:18,640 - INFO - Alternative table extraction found 2 rows on page 30
# 2025-06-10 12:35:18,948 - INFO - Alternative table extraction found 2 rows on page 34
# 2025-06-10 12:35:19,051 - INFO - Alternative table extraction found 4 rows on page 36
# 2025-06-10 12:35:19,120 - INFO - Alternative table extraction found 4 rows on page 37
# 2025-06-10 12:35:19,160 - INFO - Alternative table extraction found 3 rows on page 38
# 2025-06-10 12:35:19,214 - INFO - Alternative table extraction found 2 rows on page 39
# 2025-06-10 12:35:19,323 - INFO - Alternative table extraction found 2 rows on page 41
# 2025-06-10 12:35:19,384 - INFO - Alternative table extraction found 4 rows on page 43
# 2025-06-10 12:35:19,457 - INFO - Alternative table extraction found 3 rows on page 44
# 2025-06-10 12:35:19,509 - INFO - Alternative table extraction found 3 rows on page 45
# 2025-06-10 12:35:19,545 - INFO - Alternative table extraction found 2 rows on page 46
# 2025-06-10 12:35:19,568 - INFO - Alternative table extraction found 2 rows on page 47
# 2025-06-10 12:35:19,624 - INFO - Alternative table extraction found 3 rows on page 48
# 2025-06-10 12:35:19,672 - INFO - Alternative table extraction found 2 rows on page 49
# 2025-06-10 12:35:19,761 - INFO - Alternative table extraction found 2 rows on page 51
# 2025-06-10 12:35:19,838 - INFO - Alternative table extraction found 4 rows on page 53
# 2025-06-10 12:35:19,925 - INFO - Successfully extracted table from page 54
# 2025-06-10 12:35:20,026 - INFO - Alternative table extraction found 3 rows on page 55
# 2025-06-10 12:35:20,162 - INFO - Successfully extracted table from page 56
# 2025-06-10 12:35:20,270 - INFO - Alternative table extraction found 5 rows on page 57
# 2025-06-10 12:35:20,364 - INFO - Successfully extracted table from page 58
# 2025-06-10 12:35:20,367 - INFO - Successfully extracted table from page 58
# 2025-06-10 12:35:20,441 - INFO - Successfully extracted table from page 59
# 2025-06-10 12:35:20,643 - INFO - Successfully extracted table from page 60
# 2025-06-10 12:35:20,648 - INFO - Successfully extracted table from page 60
# 2025-06-10 12:35:20,650 - INFO - Successfully extracted table from page 60
# 2025-06-10 12:35:20,742 - INFO - Successfully extracted table from page 61
# 2025-06-10 12:35:20,745 - INFO - Successfully extracted table from page 61
# 2025-06-10 12:35:20,930 - INFO - Successfully extracted table from page 62
# 2025-06-10 12:35:20,932 - INFO - Successfully extracted table from page 62
# 2025-06-10 12:35:20,937 - INFO - Successfully extracted table from page 62
# 2025-06-10 12:35:21,032 - INFO - Successfully extracted table from page 63
# 2025-06-10 12:35:21,039 - INFO - Successfully extracted table from page 63
# 2025-06-10 12:35:21,184 - INFO - Successfully extracted table from page 64
# 2025-06-10 12:35:21,189 - INFO - Successfully extracted table from page 64
# 2025-06-10 12:35:21,319 - INFO - Successfully extracted table from page 65
# 2025-06-10 12:35:21,326 - INFO - Successfully extracted table from page 65
# 2025-06-10 12:35:21,330 - INFO - Successfully extracted table from page 65
# 2025-06-10 12:35:21,405 - INFO - Successfully extracted table from page 66
# 2025-06-10 12:35:21,584 - INFO - Successfully extracted table from page 67
# 2025-06-10 12:35:21,591 - INFO - Successfully extracted table from page 67
# 2025-06-10 12:35:21,597 - INFO - Successfully extracted table from page 67
# 2025-06-10 12:35:21,712 - INFO - Successfully extracted table from page 68
# 2025-06-10 12:35:22,037 - INFO - Successfully extracted table from page 69
# 2025-06-10 12:35:22,040 - INFO - Successfully extracted table from page 69
# 2025-06-10 12:35:22,044 - INFO - Successfully extracted table from page 69
# 2025-06-10 12:35:22,234 - INFO - Successfully extracted table from page 70
# 2025-06-10 12:35:22,238 - INFO - Successfully extracted table from page 70
# 2025-06-10 12:35:22,593 - INFO - Successfully extracted table from page 71
# 2025-06-10 12:35:22,596 - INFO - Successfully extracted table from page 71
# 2025-06-10 12:35:22,605 - INFO - Successfully extracted table from page 71
# 2025-06-10 12:35:22,658 - INFO - Successfully extracted table from page 72
# 2025-06-10 12:35:22,837 - INFO - Successfully extracted table from page 73
# 2025-06-10 12:35:22,936 - INFO - Alternative table extraction found 3 rows on page 74
# 2025-06-10 12:35:23,075 - INFO - Alternative table extraction found 3 rows on page 75
# 2025-06-10 12:35:23,277 - INFO - Successfully extracted table from page 76
# 2025-06-10 12:35:23,487 - INFO - Successfully extracted table from page 77
# 2025-06-10 12:35:23,574 - INFO - Alternative table extraction found 5 rows on page 78
# ...
# 2025-06-10 13:39:16,422 - INFO - ✅ Successfully processed: INTCV601, IN-DA Product Portfolio Introductory Program.pdf
# 2025-06-10 13:39:16,423 - INFO - Processing file 598/608: INTCV614, Electromechanical and Static Relays, Course description.pdf
# 2025-06-10 13:39:16,544 - INFO - ✅ Successfully processed: INTCV614, Electromechanical and Static Relays, Course description.pdf
# 2025-06-10 13:39:16,546 - INFO - Processing file 599/608: Trip circuit supervision relay TCS, Product Guide.pdf
# 2025-06-10 13:39:16,637 - INFO - Alternative table extraction found 9 rows on page 3
# 2025-06-10 13:39:16,897 - INFO - Successfully extracted table from page 4
# 2025-06-10 13:39:17,017 - INFO - Alternative table extraction found 2 rows on page 5
# 2025-06-10 13:39:17,422 - INFO - Successfully extracted table from page 6
# 2025-06-10 13:39:17,431 - INFO - Successfully extracted table from page 6
# 2025-06-10 13:39:17,437 - INFO - Successfully extracted table from page 6
# 2025-06-10 13:39:17,878 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:17,884 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:17,890 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:17,895 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:18,139 - INFO - Successfully extracted table from page 8
# 2025-06-10 13:39:18,145 - INFO - Successfully extracted table from page 8
# 2025-06-10 13:39:18,612 - INFO - Successfully extracted table from page 10
# 2025-06-10 13:39:18,614 - INFO - Successfully extracted table from page 10
# 2025-06-10 13:39:18,710 - INFO - Alternative table extraction found 5 rows on page 12
# 2025-06-10 13:39:19,626 - INFO - ✅ Successfully processed: Trip circuit supervision relay TCS, Product Guide.pdf
# 2025-06-10 13:39:19,628 - INFO - Processing file 600/608: Trip circuit supervision relay Type TCS.pdf
# 2025-06-10 13:39:19,806 - INFO - Alternative table extraction found 11 rows on page 2
# 2025-06-10 13:39:20,198 - INFO - Alternative table extraction found 9 rows on page 3
# 2025-06-10 13:39:20,425 - INFO - Successfully extracted table from page 4
# 2025-06-10 13:39:20,432 - INFO - Successfully extracted table from page 4
# 2025-06-10 13:39:20,738 - INFO - Successfully extracted table from page 5
# 2025-06-10 13:39:20,745 - INFO - Successfully extracted table from page 5
# 2025-06-10 13:39:21,008 - INFO - Alternative table extraction found 16 rows on page 6
# 2025-06-10 13:39:21,175 - INFO - ✅ Successfully processed: Trip circuit supervision relay Type TCS.pdf
# 2025-06-10 13:39:21,176 - INFO - Processing file 601/608: Fuse failure relay UVT92m, Product Guide.pdf
# 2025-06-10 13:39:21,259 - INFO - Alternative table extraction found 8 rows on page 3
# 2025-06-10 13:39:21,429 - INFO - Alternative table extraction found 20 rows on page 4
# 2025-06-10 13:39:22,052 - INFO - Alternative table extraction found 27 rows on page 5
# 2025-06-10 13:39:22,447 - INFO - Alternative table extraction found 21 rows on page 6
# 2025-06-10 13:39:23,094 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:23,096 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:23,098 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:23,402 - INFO - Successfully extracted table from page 8
# 2025-06-10 13:39:23,457 - INFO - Successfully extracted table from page 9
# 2025-06-10 13:39:25,037 - INFO - ✅ Successfully processed: Fuse failure relay UVT92m, Product Guide.pdf
# 2025-06-10 13:39:25,038 - INFO - Processing file 602/608: IN DPS India Training, Training center, Enrollment form.pdf
# 2025-06-10 13:39:25,380 - INFO - Successfully extracted table from page 1
# 2025-06-10 13:39:25,381 - INFO - Successfully extracted table from page 1
# 2025-06-10 13:39:25,383 - INFO - Successfully extracted table from page 1
# 2025-06-10 13:39:25,397 - INFO - ✅ Successfully processed: IN DPS India Training, Training center, Enrollment form.pdf
# 2025-06-10 13:39:25,398 - INFO - Processing file 603/608: INTCV601, IN-DA Product Portfolio Introductory Program.pdf
# 2025-06-10 13:39:25,550 - INFO - Alternative table extraction found 10 rows on page 1
# 2025-06-10 13:39:25,610 - INFO - ✅ Successfully processed: INTCV601, IN-DA Product Portfolio Introductory Program.pdf
# 2025-06-10 13:39:25,611 - INFO - Processing file 604/608: INTCV614, Electromechanical and Static Relays, Course description.pdf
# 2025-06-10 13:39:25,732 - INFO - ✅ Successfully processed: INTCV614, Electromechanical and Static Relays, Course description.pdf
# 2025-06-10 13:39:25,733 - INFO - Processing file 605/608: ABB ZEE600 - Brochure.pdf
# 2025-06-10 13:39:25,845 - INFO - Alternative table extraction found 2 rows on page 3
# 2025-06-10 13:39:26,015 - INFO - Alternative table extraction found 23 rows on page 4
# 2025-06-10 13:39:26,301 - INFO - Alternative table extraction found 16 rows on page 5
# 2025-06-10 13:39:26,510 - INFO - Successfully extracted table from page 6
# 2025-06-10 13:39:26,569 - INFO - Alternative table extraction found 5 rows on page 8
# 2025-06-10 13:39:26,659 - INFO - Alternative table extraction found 28 rows on page 9
# 2025-06-10 13:39:26,707 - INFO - Alternative table extraction found 13 rows on page 10
# 2025-06-10 13:39:27,113 - INFO - Alternative table extraction found 5 rows on page 12
# 2025-06-10 13:39:27,305 - INFO - Alternative table extraction found 6 rows on page 13
# 2025-06-10 13:39:27,350 - INFO - Alternative table extraction found 2 rows on page 16
# 2025-06-10 13:39:27,486 - INFO - Alternative table extraction found 32 rows on page 20
# 2025-06-10 13:39:27,647 - INFO - Alternative table extraction found 32 rows on page 21
# 2025-06-10 13:39:29,634 - INFO - ✅ Successfully processed: ABB ZEE600 - Brochure.pdf
# 2025-06-10 13:39:29,635 - INFO - Processing file 606/608: ABB ZEE600 - Product Guide.pdf
# 2025-06-10 13:39:29,719 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:29,930 - INFO - Alternative table extraction found 13 rows on page 3
# 2025-06-10 13:39:30,150 - INFO - Successfully extracted table from page 4
# 2025-06-10 13:39:30,242 - INFO - Successfully extracted table from page 5
# 2025-06-10 13:39:30,329 - INFO - Successfully extracted table from page 6
# 2025-06-10 13:39:30,462 - INFO - Successfully extracted table from page 7
# 2025-06-10 13:39:30,674 - INFO - Successfully extracted table from page 8
# 2025-06-10 13:39:30,693 - INFO - Successfully extracted table from page 8
# 2025-06-10 13:39:30,827 - INFO - Successfully extracted table from page 9
# 2025-06-10 13:39:30,835 - INFO - Successfully extracted table from page 9
# 2025-06-10 13:39:31,058 - INFO - Successfully extracted table from page 10
# 2025-06-10 13:39:31,343 - INFO - Successfully extracted table from page 11
# 2025-06-10 13:39:31,581 - INFO - Successfully extracted table from page 12
# 2025-06-10 13:39:31,612 - INFO - Successfully extracted table from page 13
# 2025-06-10 13:39:31,819 - INFO - Successfully extracted table from page 14
# 2025-06-10 13:39:31,880 - INFO - Successfully extracted table from page 15
# 2025-06-10 13:39:31,915 - INFO - Successfully extracted table from page 16
# 2025-06-10 13:39:32,274 - INFO - Successfully extracted table from page 17
# 2025-06-10 13:39:32,304 - INFO - Successfully extracted table from page 18
# 2025-06-10 13:39:32,378 - INFO - Successfully extracted table from page 19
# 2025-06-10 13:39:32,480 - INFO - Successfully extracted table from page 20
# 2025-06-10 13:39:32,589 - INFO - Successfully extracted table from page 21
# 2025-06-10 13:39:32,893 - INFO - Successfully extracted table from page 22
# 2025-06-10 13:39:33,233 - INFO - Successfully extracted table from page 23
# 2025-06-10 13:39:33,475 - INFO - Successfully extracted table from page 24
# 2025-06-10 13:39:33,638 - INFO - Successfully extracted table from page 25
# 2025-06-10 13:39:33,710 - INFO - Successfully extracted table from page 26
# 2025-06-10 13:39:33,855 - INFO - Successfully extracted table from page 27
# 2025-06-10 13:39:34,113 - INFO - Successfully extracted table from page 28
# 2025-06-10 13:39:34,448 - INFO - Successfully extracted table from page 29
# 2025-06-10 13:39:34,450 - INFO - Successfully extracted table from page 29
# 2025-06-10 13:39:34,559 - INFO - Successfully extracted table from page 30
# 2025-06-10 13:39:34,673 - INFO - Successfully extracted table from page 31
# 2025-06-10 13:39:34,840 - INFO - Successfully extracted table from page 32
# 2025-06-10 13:39:34,994 - INFO - Successfully extracted table from page 33
# 2025-06-10 13:39:35,158 - INFO - Successfully extracted table from page 34
# 2025-06-10 13:39:35,275 - INFO - Successfully extracted table from page 35
# 2025-06-10 13:39:35,367 - INFO - Successfully extracted table from page 36
# 2025-06-10 13:39:35,456 - INFO - Successfully extracted table from page 37
# 2025-06-10 13:39:35,491 - INFO - Successfully extracted table from page 38
# 2025-06-10 13:39:35,619 - INFO - Successfully extracted table from page 39
# 2025-06-10 13:39:35,802 - INFO - Successfully extracted table from page 40
# 2025-06-10 13:39:35,805 - INFO - Successfully extracted table from page 40
# 2025-06-10 13:39:36,037 - INFO - Successfully extracted table from page 41
# 2025-06-10 13:39:36,130 - INFO - Successfully extracted table from page 42
# 2025-06-10 13:39:36,378 - INFO - Successfully extracted table from page 43
# 2025-06-10 13:39:36,644 - INFO - Successfully extracted table from page 44
# 2025-06-10 13:39:36,871 - INFO - Successfully extracted table from page 45
# 2025-06-10 13:39:36,873 - INFO - Successfully extracted table from page 45
# 2025-06-10 13:39:37,228 - INFO - Successfully extracted table from page 46
# 2025-06-10 13:39:37,532 - INFO - Successfully extracted table from page 47
# 2025-06-10 13:39:37,534 - INFO - Successfully extracted table from page 47
# 2025-06-10 13:39:37,709 - INFO - Successfully extracted table from page 48
# 2025-06-10 13:39:37,919 - INFO - Successfully extracted table from page 49
# 2025-06-10 13:39:37,961 - INFO - Successfully extracted table from page 50
# 2025-06-10 13:39:38,082 - INFO - Successfully extracted table from page 51
# 2025-06-10 13:39:38,295 - INFO - Successfully extracted table from page 52
# 2025-06-10 13:39:38,529 - INFO - Successfully extracted table from page 53
# 2025-06-10 13:39:38,540 - INFO - Successfully extracted table from page 53
# 2025-06-10 13:39:38,790 - INFO - Successfully extracted table from page 54
# 2025-06-10 13:39:38,809 - INFO - Successfully extracted table from page 54
# 2025-06-10 13:39:39,064 - INFO - Successfully extracted table from page 55
# 2025-06-10 13:39:39,070 - INFO - Successfully extracted table from page 55
# 2025-06-10 13:39:39,079 - INFO - Successfully extracted table from page 55
# 2025-06-10 13:39:39,082 - INFO - Successfully extracted table from page 55
# 2025-06-10 13:39:39,383 - INFO - Successfully extracted table from page 56
# 2025-06-10 13:39:39,505 - INFO - Successfully extracted table from page 57
# 2025-06-10 13:39:39,600 - INFO - Successfully extracted table from page 58
# 2025-06-10 13:39:39,832 - INFO - Successfully extracted table from page 59
# 2025-06-10 13:39:39,861 - INFO - Successfully extracted table from page 59
# 2025-06-10 13:39:40,699 - INFO - Successfully extracted table from page 60
# 2025-06-10 13:39:40,709 - INFO - Successfully extracted table from page 60
# 2025-06-10 13:39:40,717 - INFO - Successfully extracted table from page 60
# 2025-06-10 13:39:40,725 - INFO - Successfully extracted table from page 60
# 2025-06-10 13:39:40,728 - INFO - Successfully extracted table from page 60
# 2025-06-10 13:39:41,746 - INFO - Successfully extracted table from page 61
# 2025-06-10 13:39:41,751 - INFO - Successfully extracted table from page 61
# 2025-06-10 13:39:41,764 - INFO - Successfully extracted table from page 61
# 2025-06-10 13:39:41,770 - INFO - Successfully extracted table from page 61
# 2025-06-10 13:39:41,774 - INFO - Successfully extracted table from page 61
# 2025-06-10 13:39:42,029 - INFO - Successfully extracted table from page 62
# 2025-06-10 13:39:42,038 - INFO - Successfully extracted table from page 62
# 2025-06-10 13:39:42,257 - INFO - Successfully extracted table from page 63
# 2025-06-10 13:39:42,260 - INFO - Successfully extracted table from page 63
# 2025-06-10 13:39:42,934 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,937 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,942 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,948 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,956 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,965 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:42,974 - INFO - Successfully extracted table from page 64
# 2025-06-10 13:39:43,763 - INFO - Successfully extracted table from page 65
# 2025-06-10 13:39:43,766 - INFO - Successfully extracted table from page 65
# 2025-06-10 13:39:43,771 - INFO - Successfully extracted table from page 65
# 2025-06-10 13:39:43,803 - INFO - Successfully extracted table from page 65
# 2025-06-10 13:39:43,811 - INFO - Successfully extracted table from page 65
# 2025-06-10 13:39:44,223 - INFO - Successfully extracted table from page 66
# 2025-06-10 13:39:44,226 - INFO - Successfully extracted table from page 66
# 2025-06-10 13:39:44,237 - INFO - Successfully extracted table from page 66
# 2025-06-10 13:39:44,240 - INFO - Successfully extracted table from page 66
# 2025-06-10 13:39:44,346 - INFO - Successfully extracted table from page 67
# 2025-06-10 13:39:44,463 - INFO - Successfully extracted table from page 68
# 2025-06-10 13:39:44,467 - INFO - Successfully extracted table from page 68
# 2025-06-10 13:39:45,792 - INFO - ✅ Successfully processed: ABB ZEE600 - Product Guide.pdf
# 2025-06-10 13:39:45,794 - INFO - Processing file 607/608: ABB ZEE600C Substation Automation Unit - Data Sheet.pdf
# 2025-06-10 13:39:46,213 - INFO - Alternative table extraction found 4 rows on page 1
# 2025-06-10 13:39:47,172 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,174 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,179 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,183 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,188 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,195 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,419 - INFO - ✅ Successfully processed: ABB ZEE600C Substation Automation Unit - Data Sheet.pdf
# 2025-06-10 13:39:47,420 - INFO - Processing file 608/608: Cybersecurity advisory - zenon LogServer.pdf
# 2025-06-10 13:39:47,533 - INFO - Alternative table extraction found 4 rows on page 1
# 2025-06-10 13:39:47,687 - INFO - Successfully extracted table from page 2
# 2025-06-10 13:39:47,808 - INFO - Alternative table extraction found 11 rows on page 3
# 2025-06-10 13:39:47,880 - INFO - Alternative table extraction found 7 rows on page 4
# 2025-06-10 13:39:48,036 - INFO - Alternative table extraction found 3 rows on page 5
# 2025-06-10 13:39:48,160 - INFO - Alternative table extraction found 3 rows on page 6
# 2025-06-10 13:39:48,360 - INFO - Alternative table extraction found 8 rows on page 7
# 2025-06-10 13:39:48,395 - INFO - Alternative table extraction found 6 rows on page 8
# 2025-06-10 13:39:48,407 - INFO - ✅ Successfully processed: Cybersecurity advisory - zenon LogServer.pdf
# 2025-06-10 13:39:48,780 - INFO - ✅ Merged corpus written to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\abb_corpus.txt
# 2025-06-10 13:39:48,781 - INFO - ✅ Final preprocessing complete!
# 2025-06-10 13:39:48,782 - INFO - 📄 Individual text files saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\individual_docs
# 2025-06-10 13:39:48,784 - INFO - 🖼️ Images extracted to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\extracted_images
# 2025-06-10 13:39:48,785 - INFO - 📘 Merged corpus written to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\abb_corpus.txt
# 2025-06-10 13:39:48,786 - INFO - 📊 Total files processed: 598/608

# %%
import os
import json
import re
from pathlib import Path
from typing import List, Dict, Tuple
import logging
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns

# Tokenizer libraries
from tokenizers import Tokenizer, models, pre_tokenizers, decoders, trainers, processors
from tokenizers.models import BPE, WordPiece
from tokenizers.trainers import BpeTrainer, WordPieceTrainer
from tokenizers.pre_tokenizers import Whitespace, ByteLevel
from tokenizers.processors import TemplateProcessing
from tokenizers.decoders import ByteLevel as ByteLevelDecoder, WordPiece as WordPieceDecoder
# Out:
# 2025-06-10 13:39:54,969 - INFO - Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2025-06-10 13:39:54,970 - INFO - NumExpr defaulting to 8 threads.

# %%
# Set up logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
logger = logging.getLogger(__name__)

class ABBTokenizerTrainer:
    """Custom tokenizer trainer for ABB technical documentation."""
    
    def __init__(self, corpus_path: str, output_dir: str):
        self.corpus_path = Path(corpus_path)
        self.output_dir = Path(output_dir)
        self.output_dir.mkdir(parents=True, exist_ok=True)
        
        # Tokenizer configurations
        self.vocab_sizes = [8000, 16000, 32000]
        self.special_tokens = ["<pad>", "<unk>", "<bos>", "<eos>", "<mask>", "=== TABLE START ===", "=== TABLE END ==="]
        
        # Statistics storage
        self.training_stats = {}
        
    def preprocess_corpus(self) -> Tuple[str, Dict]:
        """Clean and preprocess the ABB corpus for tokenizer training."""
        logger.info("Preprocessing ABB corpus...")
        
        if not self.corpus_path.exists():
            raise FileNotFoundError(f"Corpus file not found: {self.corpus_path}")
        
        with open(self.corpus_path, 'r', encoding='utf-8') as f:
            raw_text = f.read()
        
        # Clean the text
        cleaned_text = self._clean_text(raw_text)
        
        # Generate statistics
        stats = self._generate_corpus_stats(cleaned_text)
        
        # Save cleaned corpus
        cleaned_path = self.output_dir / "cleaned_corpus.txt"
        with open(cleaned_path, 'w', encoding='utf-8') as f:
            f.write(cleaned_text)
        
        logger.info(f"Cleaned corpus saved to: {cleaned_path}")
        return str(cleaned_path), stats
    
    def _clean_text(self, text: str) -> str:
        """Clean and normalize text for tokenizer training."""
        # Remove table markers
        text = re.sub(r'=== TABLE START ===.*?=== TABLE END ===', '', text, flags=re.DOTALL)
        text = re.sub(r'=== Table ===.*?=== End Table ===', '', text, flags=re.DOTALL)
        
        # Clean up document separators
        text = re.sub(r'={50,}', '\n', text)
        
        # Normalize whitespace
        text = re.sub(r'\n\s*\n', '\n\n', text)  # Multiple newlines to double newline
        text = re.sub(r'[ \t]+', ' ', text)  # Multiple spaces/tabs to single space
        
        # Preserve ABB product codes and technical terms
        # Keep alphanumeric codes like "ARC600", "IEC-104", etc.
        
        # Remove excessive punctuation
        text = re.sub(r'[.]{3,}', '...', text)
        text = re.sub(r'[-]{3,}', '---', text)
        
        # Clean up common formatting artifacts
        text = re.sub(r'\s+([.,;:!?])', r'\1', text)  # Remove space before punctuation
        
        return text.strip()
    
    def _generate_corpus_stats(self, text: str) -> Dict:
        """Generate statistics about the corpus."""
        words = text.split()
        chars = list(text)
        
        stats = {
            'total_characters': len(text),
            'total_words': len(words),
            'unique_words': len(set(words)),
            'unique_chars': len(set(chars)),
            'avg_word_length': sum(len(word) for word in words) / len(words) if words else 0,
            'vocabulary_size': len(set(word.lower() for word in words)),
        }
        
        # Find ABB-specific terms
        abb_terms = []
        patterns = [
            r'\bABB\b',
            r'\b[A-Z]{2,}\d+\b',  # Product codes like ARC600
            r'\b[A-Z]+-\d+\b',    # Standards like IEC-104
            r'\b\d+[A-Z]+\b',     # Model numbers
        ]
        
        for pattern in patterns:
            matches = re.findall(pattern, text)
            abb_terms.extend(matches)
        
        stats['abb_terms_count'] = len(abb_terms)
        stats['unique_abb_terms'] = len(set(abb_terms))
        
        return stats
    
    def train_bpe_tokenizer(self, corpus_path: str, vocab_size: int) -> Tokenizer:
        """Train a BPE tokenizer on the ABB corpus."""
        logger.info(f"Training BPE tokenizer with vocab size {vocab_size}...")
        
        # Initialize BPE tokenizer
        tokenizer = Tokenizer(BPE(unk_token="<unk>"))
        
        # Set pre-tokenizer
        tokenizer.pre_tokenizer = pre_tokenizers.Sequence([
            Whitespace(),
            ByteLevel(add_prefix_space=False)
        ])
        
        # Set decoder
        tokenizer.decoder = ByteLevelDecoder()
        
        # Configure trainer
        trainer = BpeTrainer(
            vocab_size=vocab_size,
            min_frequency=2,
            special_tokens=self.special_tokens,
            show_progress=True,
            initial_alphabet=ByteLevel.alphabet()
        )
        
        # Train the tokenizer
        tokenizer.train([corpus_path], trainer)
        
        # Add post-processor for special tokens
        tokenizer.post_processor = TemplateProcessing(
            single="<bos> $A <eos>",
            special_tokens=[("<bos>", 2), ("<eos>", 3)]
        )
        
        return tokenizer
    
    def train_wordpiece_tokenizer(self, corpus_path: str, vocab_size: int) -> Tokenizer:
        """Train a WordPiece tokenizer on the ABB corpus."""
        logger.info(f"Training WordPiece tokenizer with vocab size {vocab_size}...")
        
        # Initialize WordPiece tokenizer
        tokenizer = Tokenizer(WordPiece(unk_token="<unk>"))
        
        # Set pre-tokenizer
        tokenizer.pre_tokenizer = Whitespace()
        
        # Set decoder
        tokenizer.decoder = WordPieceDecoder()
        
        # Configure trainer
        trainer = WordPieceTrainer(
            vocab_size=vocab_size,
            min_frequency=2,
            special_tokens=self.special_tokens,
            show_progress=True
        )
        
        # Train the tokenizer
        tokenizer.train([corpus_path], trainer)
        
        # Add post-processor for special tokens
        tokenizer.post_processor = TemplateProcessing(
            single="<bos> $A <eos>",
            special_tokens=[("<bos>", 2), ("<eos>", 3)]
        )
        
        return tokenizer
    
    def evaluate_tokenizer(self, tokenizer: Tokenizer, test_text: str, name: str) -> Dict:
        """Evaluate tokenizer performance on test text."""
        logger.info(f"Evaluating {name} tokenizer...")
        
        # Encode test text
        encoding = tokenizer.encode(test_text)
        tokens = encoding.tokens
        
        # Calculate metrics
        metrics = {
            'name': name,
            'num_tokens': len(tokens),
            'num_characters': len(test_text),
            'compression_ratio': len(test_text) / len(tokens) if tokens else 0,
            'vocab_size': tokenizer.get_vocab_size(),
            'unk_count': sum(1 for token in tokens if token == '<unk>'),
            'unk_ratio': sum(1 for token in tokens if token == '<unk>') / len(tokens) if tokens else 0
        }
        
        # Sample tokenization examples
        sample_texts = [
            "ABB Wireless Controller ARC600 provides remote monitoring capabilities.",
            "The IEC-104 protocol ensures reliable communication in distribution networks.",
            "System Average Interruption Duration Index (SAIDI) measurements show improvement.",
            "Configure the switching devices using I/O expansion modules."
        ]
        
        examples = []
        for text in sample_texts:
            encoding = tokenizer.encode(text)
            examples.append({
                'text': text,
                'tokens': encoding.tokens,
                'token_count': len(encoding.tokens)
            })
        
        metrics['examples'] = examples
        return metrics
    
    def save_tokenizer(self, tokenizer: Tokenizer, name: str, vocab_size: int):
        """Save tokenizer to files."""
        tokenizer_dir = self.output_dir / f"{name}_tokenizer_{vocab_size}"
        tokenizer_dir.mkdir(exist_ok=True)
        
        # Save tokenizer
        tokenizer.save(str(tokenizer_dir / "tokenizer.json"))
        
        # Save vocabulary
        vocab = tokenizer.get_vocab()
        with open(tokenizer_dir / "vocab.json", 'w', encoding='utf-8') as f:
            json.dump(vocab, f, indent=2, ensure_ascii=False)
        
        # Save vocab as text file
        with open(tokenizer_dir / "vocab.txt", 'w', encoding='utf-8') as f:
            for token, idx in sorted(vocab.items(), key=lambda x: x[1]):
                f.write(f"{token}\n")
        
        logger.info(f"Tokenizer saved to: {tokenizer_dir}")
        return tokenizer_dir
    
    def compare_tokenizers(self, metrics_list: List[Dict]):
        """Compare different tokenizers and generate report."""
        logger.info("Generating tokenizer comparison report...")
        
        # Create comparison DataFrame-like structure
        comparison_data = []
        for metrics in metrics_list:
            comparison_data.append({
                'Name': metrics['name'],
                'Vocabulary Size': metrics['vocab_size'],
                'Compression Ratio': f"{metrics['compression_ratio']:.2f}",
                'Unknown Token %': f"{metrics['unk_ratio']*100:.2f}%",
                'Tokens Generated': metrics['num_tokens']
            })
        
        # Save comparison report
        report_path = self.output_dir / "tokenizer_comparison.json"
        with open(report_path, 'w', encoding='utf-8') as f:
            json.dump({
                'comparison_summary': comparison_data,
                'detailed_metrics': metrics_list
            }, f, indent=2, ensure_ascii=False)
        
        # Generate text report
        text_report_path = self.output_dir / "tokenizer_comparison.txt"
        with open(text_report_path, 'w', encoding='utf-8') as f:
            f.write("ABB Tokenizer Comparison Report\n")
            f.write("=" * 50 + "\n\n")
            
            for data in comparison_data:
                f.write(f"Tokenizer: {data['Name']}\n")
                f.write(f"  Vocabulary Size: {data['Vocabulary Size']}\n")
                f.write(f"  Compression Ratio: {data['Compression Ratio']} chars/token\n")
                f.write(f"  Unknown Token Rate: {data['Unknown Token %']}\n")
                f.write(f"  Tokens Generated: {data['Tokens Generated']}\n\n")
            
            # Add recommendations
            f.write("Recommendations:\n")
            f.write("-" * 20 + "\n")
            
            best_compression = max(metrics_list, key=lambda x: x['compression_ratio'])
            best_coverage = min(metrics_list, key=lambda x: x['unk_ratio'])
            
            f.write(f"Best Compression: {best_compression['name']} ({best_compression['compression_ratio']:.2f} chars/token)\n")
            f.write(f"Best Coverage: {best_coverage['name']} ({best_coverage['unk_ratio']*100:.2f}% unknown tokens)\n")
        
        logger.info(f"Comparison reports saved to: {report_path} and {text_report_path}")
    
    def train_all_tokenizers(self):
        """Train all tokenizer variants and compare them."""
        logger.info("Starting comprehensive tokenizer training...")
        
        # Preprocess corpus
        cleaned_corpus_path, corpus_stats = self.preprocess_corpus()
        
        # Save corpus statistics
        stats_path = self.output_dir / "corpus_statistics.json"
        with open(stats_path, 'w', encoding='utf-8') as f:
            json.dump(corpus_stats, f, indent=2)
        
        logger.info(f"Corpus statistics: {corpus_stats}")
        
        # Load test text for evaluation
        with open(cleaned_corpus_path, 'r', encoding='utf-8') as f:
            full_text = f.read()
        
        # Use first 10% of text for evaluation
        test_text = full_text[:len(full_text)//10]
        
        all_metrics = []
        
        # Train tokenizers for different vocab sizes
        for vocab_size in self.vocab_sizes:
            # Train BPE tokenizer
            bpe_tokenizer = self.train_bpe_tokenizer(cleaned_corpus_path, vocab_size)
            bpe_metrics = self.evaluate_tokenizer(bpe_tokenizer, test_text, f"BPE_{vocab_size}")
            all_metrics.append(bpe_metrics)
            self.save_tokenizer(bpe_tokenizer, "BPE", vocab_size)
            
            # Train WordPiece tokenizer
            wp_tokenizer = self.train_wordpiece_tokenizer(cleaned_corpus_path, vocab_size)
            wp_metrics = self.evaluate_tokenizer(wp_tokenizer, test_text, f"WordPiece_{vocab_size}")
            all_metrics.append(wp_metrics)
            self.save_tokenizer(wp_tokenizer, "WordPiece", vocab_size)
        
        # Generate comparison report
        self.compare_tokenizers(all_metrics)
        
        logger.info("✅ Tokenizer training complete!")
        logger.info(f"📁 All outputs saved to: {self.output_dir}")
        
        return all_metrics

# %%
def main():
    """Main function to run tokenizer training."""
    
    # Configuration
    corpus_path = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\abb_corpus.txt"
    output_dir = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers"
    
    # Initialize trainer
    trainer = ABBTokenizerTrainer(corpus_path, output_dir)
    
    try:
        # Train all tokenizers
        metrics = trainer.train_all_tokenizers()
        
        # Print summary
        print("\n" + "="*60)
        print("TOKENIZER TRAINING SUMMARY")
        print("="*60)
        
        for metric in metrics:
            print(f"\n{metric['name']}:")
            print(f"  Vocabulary Size: {metric['vocab_size']:,}")
            print(f"  Compression Ratio: {metric['compression_ratio']:.2f} chars/token")
            print(f"  Unknown Token Rate: {metric['unk_ratio']*100:.2f}%")
            
            # Show first example
            if metric['examples']:
                example = metric['examples'][0]
                print(f"  Example: '{example['text']}'")
                print(f"  Tokens: {example['tokens'][:5]}..." if len(example['tokens']) > 5 else f"  Tokens: {example['tokens']}")
        
        print(f"\n📁 All tokenizer files saved to: {output_dir}")
        print("✅ Ready for Step 3: SLM Architecture Building!")
        
    except Exception as e:
        logger.error(f"Error during tokenizer training: {e}")
        raise

if __name__ == "__main__":
    main()
# Out:
# 2025-06-10 13:40:01,053 - INFO - Starting comprehensive tokenizer training...
# 2025-06-10 13:40:01,055 - INFO - Preprocessing ABB corpus...
# 2025-06-10 13:40:07,280 - INFO - Cleaned corpus saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\cleaned_corpus.txt
# 2025-06-10 13:40:07,299 - INFO - Corpus statistics: {'total_characters': 19322004, 'total_words': 3157414, 'unique_words': 56324, 'unique_chars': 258, 'avg_word_length': 5.113947046538718, 'vocabulary_size': 49980, 'abb_terms_count': 37190, 'unique_abb_terms': 1559}
# 2025-06-10 13:40:07,410 - INFO - Training BPE tokenizer with vocab size 8000...
# 2025-06-10 13:40:10,936 - INFO - Evaluating BPE_8000 tokenizer...
# 2025-06-10 13:40:12,431 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\BPE_tokenizer_8000
# 2025-06-10 13:40:12,433 - INFO - Training WordPiece tokenizer with vocab size 8000...
# 2025-06-10 13:40:14,071 - INFO - Evaluating WordPiece_8000 tokenizer...
# 2025-06-10 13:40:14,947 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\WordPiece_tokenizer_8000
# 2025-06-10 13:40:14,949 - INFO - Training BPE tokenizer with vocab size 16000...
# 2025-06-10 13:40:18,616 - INFO - Evaluating BPE_16000 tokenizer...
# 2025-06-10 13:40:20,252 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\BPE_tokenizer_16000
# 2025-06-10 13:40:20,253 - INFO - Training WordPiece tokenizer with vocab size 16000...
# 2025-06-10 13:40:22,117 - INFO - Evaluating WordPiece_16000 tokenizer...
# 2025-06-10 13:40:23,018 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\WordPiece_tokenizer_16000
# 2025-06-10 13:40:23,019 - INFO - Training BPE tokenizer with vocab size 32000...
# 2025-06-10 13:40:27,006 - INFO - Evaluating BPE_32000 tokenizer...
# 2025-06-10 13:40:28,461 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\BPE_tokenizer_32000
# 2025-06-10 13:40:28,462 - INFO - Training WordPiece tokenizer with vocab size 32000...
# 2025-06-10 13:40:30,732 - INFO - Evaluating WordPiece_32000 tokenizer...
# 2025-06-10 13:40:31,611 - INFO - Tokenizer saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\WordPiece_tokenizer_32000
# 2025-06-10 13:40:31,613 - INFO - Generating tokenizer comparison report...
# 2025-06-10 13:40:31,619 - INFO - Comparison reports saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\tokenizer_comparison.json and C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers\tokenizer_comparison.txt
# 2025-06-10 13:40:31,619 - INFO - ✅ Tokenizer training complete!
# 2025-06-10 13:40:31,620 - INFO - 📁 All outputs saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers
# ============================================================
# TOKENIZER TRAINING SUMMARY
# ============================================================
#
# BPE_8000:
#   Vocabulary Size: 8,000
#   Compression Ratio: 4.77 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Control', 'ler']...
#
# WordPiece_8000:
#   Vocabulary Size: 8,000
#   Compression Ratio: 4.72 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Control', '##ler']...
#
# BPE_16000:
#   Vocabulary Size: 16,000
#   Compression Ratio: 5.00 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Controller', 'ARC']...
#
# WordPiece_16000:
#   Vocabulary Size: 16,000
#   Compression Ratio: 5.03 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Controller', 'ARC600']...
#
# BPE_32000:
#   Vocabulary Size: 23,383
#   Compression Ratio: 5.05 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Controller', 'ARC']...
#
# WordPiece_32000:
#   Vocabulary Size: 29,434
#   Compression Ratio: 5.14 chars/token
#   Unknown Token Rate: 0.00%
#   Example: 'ABB Wireless Controller ARC600 provides remote monitoring capabilities.'
#   Tokens: ['<bos>', 'ABB', 'Wireless', 'Controller', 'ARC600']...
#
# 📁 All tokenizer files saved to: C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_grok\tokenizers
# ✅ Ready for Step 3: SLM Architecture Building!

# %%
from tokenizers import Tokenizer

tokenizer_path = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_updated\tokenizers\BPE_tokenizer_32000\tokenizer.json"
tokenizer = Tokenizer.from_file(tokenizer_path)

# Test encoding
ids = tokenizer.encode("Wireless Controller ARC600 supports IEC-104 protocol.").ids
print(ids)
# Out:
# [2, 6700, 8902, 3172, 705, 1905, 578, 19, 2979, 810, 20, 3]

# %%
from tokenizers import Tokenizer

# Load your tokenizer
tokenizer_path = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_updated\tokenizers\WordPiece_tokenizer_32000\tokenizer.json"
tokenizer = Tokenizer.from_file(tokenizer_path)

# Sample text
text = "Wireless Controller ARC600 supports IEC-104 protocol succeeding."

# Encode and get both tokens and ids
encoding = tokenizer.encode(text)

tokens = encoding.tokens
token_ids = encoding.ids

# Print side-by-side
print("🧾 Tokenized Output:")
for token, id_ in zip(tokens, token_ids):
    print(f"{token:20} --> {id_}")
# Out:
# 🧾 Tokenized Output:
# <bos>                --> 2
# Wireless             --> 7607
# Controller           --> 10178
# ARC600               --> 9841
# supports             --> 2174
# IEC                  --> 767
# -                    --> 41
# 104                  --> 3378
# protocol             --> 1010
# succeeding           --> 27857
# .                    --> 42
# <eos>                --> 3

# %%
from tokenizers import Tokenizer

# Load your tokenizer
tokenizer_path = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_updated\tokenizers\WordPiece_tokenizer_32000\tokenizer.json"
tokenizer = Tokenizer.from_file(tokenizer_path)

# Sample text
text = "Wireless Controller ARC600 supports IEC-104 protocol succeeding."

# Encode and get both tokens and ids
encoding = tokenizer.encode(text)

tokens = encoding.tokens
token_ids = encoding.ids

# Print side-by-side
print("🧾 Tokenized Output:")
for token, id_ in zip(tokens, token_ids):
    print(f"{token:20} --> {id_}")
# Out:
# 🧾 Tokenized Output:
# <bos>                --> 2
# Wireless             --> 7607
# Controller           --> 10178
# ARC600               --> 9841
# supports             --> 2174
# IEC                  --> 767
# -                    --> 41
# 104                  --> 3378
# protocol             --> 1010
# succeeding           --> 27857
# .                    --> 42
# <eos>                --> 3

# %%
from tokenizers import Tokenizer

# Load your tokenizer
tokenizer_path = r"C:\Users\INKARED5\OneDrive - ABB\Karan_ABB_Internship\Projects\Data\processed_final_updated\tokenizers_best\bpe_tokenizer_32000.json"
tokenizer = Tokenizer.from_file(tokenizer_path)

# Sample text
text = "Wireless Controller ARC600 supports IEC-104 protocol succeeding."

# Encode and get both tokens and ids
encoding = tokenizer.encode(text)

tokens = encoding.tokens
token_ids = encoding.ids

# Print side-by-side
print("🧾 Tokenized Output:")
for token, id_ in zip(tokens, token_ids):
    print(f"{token:20} --> {id_}")
# Out:
# 🧾 Tokenized Output:
# <bos>                --> 0
# ĠWireless            --> 11578
# ĠController          --> 14153
# Ġ                    --> 4360
# ARC600               --> 162
# Ġsupports            --> 6895
# Ġ                    --> 4360
# IEC-104              --> 1779
# Ġprotocol            --> 5192
# Ġsucceed             --> 15482
# ing                  --> 4414
# .                    --> 4209
# <eos>                --> 1
